# %%
import os
import json
import time
from concurrent.futures import ThreadPoolExecutor
import threading
import time
from pytube import Search
import logging
import random
logging.getLogger().setLevel(logging.ERROR)

# %%
_QUEUED = 0
_WORKING = 0
_DOWNLOADING = 0

_SKIPPED = 0
_EXCEPTIONED = 0
_DOWNLOADED = 0

_SEARCH_QUEUE = 0
_SEARCH_WORKING = 0

def attempt_download(yt_obj, existing_videos, location):
    global _SKIPPED, _EXCEPTIONED, _DOWNLOADING, _DOWNLOADED, _WORKING
    vid = yt_obj.video_id
    
    # print(vid, "attempt_download called")
    if vid in existing_videos:
        # print(vid, "Skipping, found existing folder.")
        with lock:
            _SKIPPED += 1
            _WORKING -= 1
        return 0
        
    os.makedirs(location + vid)
    try:
        stream = yt_obj.streams.get_by_itag(139)
    except Exception as e:
        print(vid, "Stopping download because of Exception", e)
        with lock:
            _EXCEPTIONED += 1
            _WORKING -= 1
        return 0

    with lock:
        _DOWNLOADING += 1
    stream.download(output_path = location + vid + "/", filename = "audio.mp4")
    # print(vid, "Audio downloaded")
    
    # print(vid, "Found captions for", list(yt_obj.captions.keys()))
    for caption in yt_obj.captions:
        if "en" in caption.code:
            a_en_caption = caption.json_captions
            json.dump(a_en_caption, open(location + vid + "/caption-" + caption.code + ".json", 'w'))
            # print(vid, "Downloaded", caption.code, "captions")
    
    existing_videos.add(yt_obj.video_id)
    with lock:
        _DOWNLOADED += 1
        _DOWNLOADING -= 1
        _WORKING -= 1
    return 1

def deep_search(search_term, existing_videos, location, depth):
    global _SEARCH_QUEUE, _SEARCH_WORKING, _QUEUED, _WORKING
    
    print("STARTING SEARCH TERM", search_term)
    
    with lock:
        _SEARCH_QUEUE -= 1
        _SEARCH_WORKING += 1
        
    # print("Search", search_term, "Performing search at depth", depth)
    search = Search(search_term)
    search.results
    for _ in range(depth - 1):
        time.sleep(random.uniform(0, 2))
        search.get_next_results()
        
    # print("Search", search_term, "Found", len(search.results), "videos")
    # print(search.results)

    start_time = time.time()
    search_results = len(search.results)
    hits = 0

    with lock:
        _QUEUED += search_results

    # print(search.results)
    for yt in search.results:
        # print(yt)
        with lock:
            _QUEUED -= 1
            _WORKING += 1
        hits += attempt_download(yt, existing_videos, location)
    
    duration = time.time() - start_time
    with lock:
        _SEARCH_WORKING -= 1
    print("COMPLETED SEARCH TERM", search_term, "|", str(int(duration)), "seconds |", str(int(search_results)), "results |", str(int(hits)), "downloaded")
    return attempts, success

"""
Added
"""
existing_dirs_file = "combined_folders_11am_feb22.txt"
existing_videos_from_file = set()
with open(existing_dirs_file, 'r') as file:
    for line in file:
        parts = line.strip().split('/')
        if len(parts) > 1:
            existing_videos_from_file.add(parts[1])
print(len(existing_videos_from_file))

"""
Done Adding
"""

existing_dirs_on_machine = ["dataset-5/", "dataset-6/", "dataset-a-2/"]
existing_videos_on_machine = {file for directory in existing_dirs_on_machine for file in os.listdir(directory)}
print(len(existing_videos_on_machine))

existing_videos = existing_videos_on_machine | existing_videos_from_file
print(len(existing_videos))

def perform_search(search_term):
    depth = 5
    location = "dataset-a-2/"
    deep_search(search_term, existing_videos, location, depth)
# Out:
# 114628
# 56901
# 132936

# %%
def print_summary_periodically(interval, diff_interval):
    cnt = 0
    while True:
        cnt += 1
        time.sleep(interval)
        with lock:
            print(cnt, int(time.time()), "| Queued:", _QUEUED, "| Working:", _WORKING, "| Downloading:", _DOWNLOADING, "| Good:", _DOWNLOADED, "| Skip:", _SKIPPED, "| Error:", _EXCEPTIONED, "| Term Queue:", _SEARCH_QUEUE, "| Term Working:", _SEARCH_WORKING)
        if searches_done:
            break

# %%
# Dataset 1, Depth 3
"""
search_terms = [
    "Joe Biden", "Kamala Harris", "Donald Trump", "Mike Pence", "Ron DeSantis",
    "Barack Obama", "Angela Merkel", "Vladimir Putin", "Xi Jinping", "Emmanuel Macron",
    "Narendra Modi", "Jair Bolsonaro", "Justin Trudeau", "Boris Johnson", "Jacinda Ardern",
    "Leonardo DiCaprio", "Meryl Streep", "Denzel Washington", "Tom Hanks", "Jennifer Lawrence",
    "Scarlett Johansson", "Brad Pitt", "Angelina Jolie", "Johnny Depp", "Nicole Kidman",
    "Beyoncé", "Taylor Swift", "Kanye West", "Rihanna", "Jay-Z",
    "Drake", "Adele", "Ed Sheeran", "Justin Bieber", "Lady Gaga",
    "Cristiano Ronaldo", "Lionel Messi", "LeBron James", "Serena Williams", "Roger Federer",
    "Usain Bolt", "Michael Phelps", "Simone Biles", "Novak Djokovic", "Tiger Woods",
    "Elon Musk", "Jeff Bezos", "Bill Gates", "Mark Zuckerberg", "Warren Buffett",
    "Tim Cook", "Larry Page", "Sergey Brin", "Jack Ma", "Mukesh Ambani",
    "Oprah Winfrey", "Ellen DeGeneres", "Kim Kardashian", "Kylie Jenner", "Greta Thunberg",
    "Malala Yousafzai", "Dalai Lama", "Pope Francis", "Donald Glover", "Dave Chappelle",
    "Stephen King", "J.K. Rowling", "George R.R. Martin", "Neil Gaiman", "Margaret Atwood",
    "Steven Spielberg", "Christopher Nolan", "Quentin Tarantino", "Martin Scorsese", "Wes Anderson",
    "Ariana Grande", "Snoop Dogg", "Eminem", "Shakira", "Katy Perry",
    "Dwayne Johnson", "Chris Hemsworth", "Robert Downey Jr.", "Hugh Jackman", "Ryan Reynolds"
]
"""

# Dataset 2, Depth 3
"""
search_terms = [
    "Apple", "Microsoft", "Google", "Amazon", "Facebook",
    "Berkshire Hathaway", "Visa", "Johnson & Johnson", "Walmart", "Procter & Gamble",
    "Intel", "Verizon Communications", "AT&T", "Coca-Cola", "Pfizer",
    "Chevron", "Home Depot", "Merck & Co.", "Disney", "Cisco Systems",
    "IBM", "Boeing", "Goldman Sachs", "McDonald's", "3M",
    "Nike", "American Express", "UnitedHealth Group", "ExxonMobil", "General Electric",
    "JP Morgan Chase", "Morgan Stanley", "Tesla", "Netflix", "Adobe Systems",
    "Salesforce", "Oracle", "PayPal", "Qualcomm", "AMD",
    "eBay", "General Motors", "Ford Motor Company", "Delta Air Lines", "United Airlines",
    "Lockheed Martin", "Raytheon Technologies", "Northrop Grumman", "General Dynamics", "Honeywell",
    "Caterpillar", "DuPont", "FedEx", "UPS", "Booz Allen Hamilton",
    "Charles Schwab", "Citigroup", "Bank of America", "Wells Fargo", "Goldman Sachs Group",
    "American Airlines Group", "Southwest Airlines", "Gilead Sciences", "Bristol-Myers Squibb", "Amgen",
    "Biogen", "Celgene", "AbbVie", "Eli Lilly and Company", "Merck",
    "Snap Inc.", "Twitter", "LinkedIn", "Spotify", "Square",
    "Lyft", "Uber Technologies", "Airbnb", "SpaceX", "Palantir Technologies",
    "Stripe", "Robinhood", "Coinbase", "Zoom Video Communications", "Slack Technologies",
    "Dell Technologies", "HP Inc.", "IBM Corporation", "Intel Corporation", "Micron Technology",
    "NVIDIA", "Broadcom Inc.", "Texas Instruments", "Qualtrics", "Snowflake",
    "DoorDash", "Instacart", "Etsy", "Roku", "Pinterest"
]
"""

# Dataset 3
"""
search_terms = [
    "True Crime Stories", "Startup Founders", "Health and Wellness Tips", "Investing for Beginners", "Science Discoveries",
    "History Mysteries", "Technology Innovations", "Mindfulness and Meditation", "Global News Analysis", "Book Review Series",
    "Comedy Shows", "Film Criticism", "Music Industry Insights", "Sports Commentary", "Fashion Trends",
    "Culinary Arts", "Language Learning", "Travel Adventures", "Parenting Advice", "Personal Finance Strategies",
    "Political Analysis", "Art and Design", "Entrepreneurship Lessons", "Educational Strategies", "Mental Health Support",
    "Fitness Coaching", "Environmental Conservation", "Digital Marketing", "Philosophy and Ethics", "Astronomy and Space",
    "Mythology and Folklore", "Cybersecurity Updates", "Blockchain and Cryptocurrency", "Artificial Intelligence Trends", "Real Estate Investing",
    "Sustainability Practices", "Creative Writing", "Public Speaking Tips", "Career Development", "Classical Music Appreciation",
    "Video Game Reviews", "Comics and Graphic Novels", "Quantum Computing", "Social Media Strategies", "DIY Home Projects",
    "Yoga and Pilates", "Pet Care and Training", "Indie Film Making", "Jazz Music Exploration", "Virtual Reality Experiences"
]
"""

# Dataset 3
"""
search_terms = [
    "TED Talk Artificial Intelligence", "TED Talk Blockchain Technology", "TED Talk Climate Change", "TED Talk Cybersecurity", "TED Talk Data Privacy",
    "TED Talk Digital Health", "TED Talk E-commerce Trends", "TED Talk Future of Work", "TED Talk Genetic Engineering", "TED Talk Green Energy",
    "TED Talk Human Rights", "TED Talk Innovation in Education", "TED Talk Journalism and Media", "TED Talk Leadership and Management", "TED Talk Mental Health",
    "TED Talk Neurotechnology", "TED Talk Online Learning", "TED Talk Pandemic Response", "TED Talk Quantum Computing", "TED Talk Racial Equality",
    "TED Talk Renewable Resources", "TED Talk Space Exploration", "TED Talk Sustainable Living", "TED Talk Technology and Society", "TED Talk Universal Basic Income",
    "TED Talk Virtual Reality", "TED Talk Women in STEM", "TED Talk Xenotransplantation", "TED Talk Youth Activism", "TED Talk Zero Waste Lifestyle",
    "TED Talk Creative Problem Solving", "TED Talk Digital Nomads", "TED Talk Emotional Intelligence", "TED Talk Financial Literacy", "TED Talk Globalization and Trade",
    "TED Talk Health and Nutrition", "TED Talk Immigrant Experiences", "TED Talk Job Automation", "TED Talk Knowledge Sharing", "TED Talk Language Preservation",
    "TED Talk Mindfulness and Meditation", "TED Talk Nature Conservation", "TED Talk Open Source Software", "TED Talk Political Polarization", "TED Talk Quantum Teleportation",
    "TED Talk Refugee Crisis", "TED Talk Social Entrepreneurship", "TED Talk Telemedicine", "TED Talk Urban Planning", "TED Talk Vaccine Development"
]
"""

# Dataset 3
"""
search_terms = [
    "Khan Academy", "CrashCourse", "TED-Ed", "National Geographic", "SciShow",
    "MinutePhysics", "Vsauce", "CGP Grey", "Veritasium", "SmarterEveryDay",
    "AsapSCIENCE", "Physics Girl", "Numberphile", "Kurzgesagt – In a Nutshell", "BBC Earth",
    "The School of Life", "Big Think", "PBS Space Time", "3Blue1Brown", "BrainCraft",
    "Extra Credits", "Deep Look", "It's Okay To Be Smart", "The Royal Institution", "Practical Engineering",
    "Historia Civilis", "The Art Assignment", "TEDx Talks", "Computerphile", "Seeker",
    "Vsauce2", "Vsauce3", "Wendover Productions", "Real Engineering", "Biographics",
    "SciShow Space", "SciShow Psych", "MinuteEarth", "Tom Scott", "Cody'sLab",
    "Nerdwriter1", "PolyMatter", "Half as Interesting", "TierZoo", "PBS Eons",
    "The Infographics Show", "Overly Sarcastic Productions", "PatrickJMT", "Sixty Symbols", "Geography Now"
]
"""

# Dataset 4, Depth 3
"""
search_terms = [
    "Unbox Therapy", "Marques Brownlee", "Linus Tech Tips", "Dave Lee", "Jonathan Morrison",
    "Austin Evans", "TechSource", "JerryRigEverything", "CNET", "The Verge",
    "MKBHD", "TechRadar", "Engadget", "TLD Today", "UrAvgConsumer",
    "Flossy Carter", "PhoneBuff", "iJustine", "What's Inside?", "TechSmartt",
    "Mrwhosetheboss", "Pocketnow", "SuperSaf TV", "TechnoBuffalo", "Android Authority",
    "Jenna Ezarik", "Lou Later", "Tech Chap", "MobileTechReview", "EverythingApplePro",
    "TechMeOut", "GadgetMatch", "Erica Griffin", "TheUnlockr", "Zollotech",
    "Booredatwork.com", "TechCrunch", "GSMArena Official", "Geekyranjit", "Tech Spurt",
    "Safwan Ahmedmia (SuperSaf)", "Chris Stuckmann", "Canoopsy", "DetroitBORG", "iGyaan",
    "Krystal Lora", "Matthew Moniz", "Michael Fisher", "Mr Mobile", "Dave2D"
]
"""

# Dataset 4, Depth 3
"""search_terms = [
    "Tasty", "Binging with Babish", "Rosanna Pansino", "Gordon Ramsay", "Jamie Oliver",
    "King of Random", "5-Minute Crafts", "Bright Side", "ThreadBanger", "Laura in the Kitchen",
    "Yoga With Adriene", "FitnessBlender", "Bob Ross", "Adam Savage’s Tested", "Anne Reardon - How To Cook That",
    "Clean My Space", "Garden Answer", "Home Repair Tutor", "This Old House", "Man Sewing",
    "The Sorry Girls", "Makeup Geek", "Wayne Goss", "FreeCodeCamp.org", "Traversy Media",
    "Justin Guitar", "Drumeo", "Chess.com", "Peter McKinnon", "PHLEARN",
    "Sewing Parts Online", "Crazy Russian Hacker", "Primitive Technology", "Grant Thompson", "The Art Sherpa",
    "Blender Guru", "Langfocus", "Easy Languages", "Khan Academy", "CG Cookie",
    "JunsKitchen", "Maangchi", "ChefSteps", "Joshua Weissman", "Food Wishes",
    "Gentle Whispering ASMR", "The Coding Train", "Corey Schafer", "Academy of Ideas", "School of Life"
]"""

# Dataset 4, Depth 3
"""search_terms = [
    "Casey Neistat", "Zoella", "Logan Paul", "Shaytards", "Jenna Marbles",
    "David Dobrik", "PewDiePie", "Roman Atwood Vlogs", "Tyler Oakley", "Connor Franta",
    "FunForLouis", "Tanya Burr", "PointlessBlogVlogs", "Safiya Nygaard", "Dude Perfect",
    "Liza Koshy", "The Dolan Twins", "Emma Chamberlain", "James Charles", "Jeffree Star",
    "NikkieTutorials", "Shane Dawson", "Trisha Paytas", "Gigi Gorgeous", "Joey Graceffa",
    "The Ace Family", "The Michalaks", "Sailing La Vagabonde", "Jon Olsson", "Erik Conover",
    "Louis Cole", "Wil Dasovich", "Raya Was Here", "Lost LeBlanc", "Kara and Nate",
    "Sam Kolder", "Peter McKinnon", "Exploring Alternatives", "Vanessa Lau", "GaryVee",
    "Ben Brown", "Lavendaire", "Mimi Ikonn", "Alex Ikonn", "Rachel Aust",
    "The Bucket List Family", "Flying The Nest", "Kombi Life", "Eileen Aldis", "Bald and Bankrupt"
]"""


# Dataset 4, Depth 3
"""
search_terms = [
    "Intelligence Squared Debates", "Oxford Union", "Cambridge Union", "TED Conferences", "The Doha Debates",
    "Big Think", "The Aspen Institute", "World Economic Forum", "National Geographic", "PBS NewsHour",
    "Democracy Now!", "The Rubin Report", "C-SPAN", "Hoover Institution", "Council on Foreign Relations",
    "Carnegie Council for Ethics in International Affairs", "The Heritage Foundation", "Brookings Institution", "Chatham House", "American Enterprise Institute",
    "Pew Research Center", "The Economist", "Financial Times", "Vox Media", "Vice News",
    "Real Time with Bill Maher", "The Agenda with Steve Paikin", "The Royal Society", "London School of Economics and Political Science", "Harvard University",
    "Stanford University", "Yale University", "Princeton University", "MIT Media Lab", "University of California Television",
    "The New School", "New York Public Library", "Chicago Ideas", "TEDx Talks", "92nd Street Y",
    "Sydney Opera House Talks & Ideas", "RSA Events", "Skepticon", "How To Academy", "Battle of Ideas"
]
"""

# Dataset 5, Depth 5
"""
search_terms = [
    "Classical Mechanics", "Quantum Mechanics", "Thermodynamics", "Electromagnetism", "Relativity",
    "Statistical Mechanics", "Condensed Matter Physics", "Particle Physics", "Nuclear Physics", "Astrophysics",
    "Cosmology", "Fluid Dynamics", "Plasma Physics", "Field Theory", "Chaos Theory",
    "Quantum Field Theory", "String Theory", "Quantum Gravity", "Loop Quantum Gravity", "Quantum Electrodynamics",
    "Quantum Chromodynamics", "Electroweak Interaction", "Strong Nuclear Force", "Weak Nuclear Force", "General Relativity",
    "Special Relativity", "Photonics", "Optics", "Acoustics", "Solid State Physics",
    "Superconductivity", "Superfluidity", "Magnetism", "Electronics", "Quantum Computing",
    "Photovoltaics", "Nanotechnology", "Materials Science", "Energy Physics", "Biophysics",
    "Geophysics", "Meteorology", "Environmental Physics", "Medical Physics", "Neurophysics",
    "Quantum Optics", "Atomic Physics", "Molecular Physics", "Femtoscience", "Nanophysics",
    "Cryogenics", "Photonics", "Nuclear Fusion", "Nuclear Fission", "Particle Accelerators",
    "Higgs Boson", "Quantum Tunneling", "Quantum Entanglement", "Quantum Superposition", "Quantum Decoherence",
    "Bell's Theorem", "Schrodinger's Cat", "Heisenberg Uncertainty Principle", "Pauli Exclusion Principle", "Fermi-Dirac Statistics",
    "Bose-Einstein Condensate", "Wave-Particle Duality", "Michelson-Morley Experiment", "LIGO", "Gravitational Waves",
    "Dark Matter", "Dark Energy", "Black Holes", "White Dwarfs", "Neutron Stars",
    "Supernovae", "Galaxies", "The Big Bang Theory", "Cosmic Microwave Background", "Inflation Theory",
    "Multiverse Theory", "Quantum Fluctuations", "Spacetime Singularities", "Wormholes", "Time Dilation",
    "Lorentz Transformation", "Gauge Theory", "Topological Defects", "Quantum Anomalies", "Entropy",
    "Second Law of Thermodynamics", "Carnot Cycle", "Maxwell's Equations", "Gauss's Law", "Faraday's Law",
    "Atomic Structure", "Periodic Table", "Chemical Bonds", "Molecular Geometry", "Stoichiometry",
    "Thermochemistry", "Chemical Kinetics", "Chemical Equilibrium", "Acids and Bases", "Redox Reactions",
    "Electrochemistry", "Quantum Chemistry", "Spectroscopy", "Chromatography", "Mass Spectrometry",
    "Nuclear Chemistry", "Organic Chemistry", "Inorganic Chemistry", "Physical Chemistry", "Analytical Chemistry",
    "Biochemistry", "Environmental Chemistry", "Industrial Chemistry", "Polymer Chemistry", "Pharmaceutical Chemistry",
    "Green Chemistry", "Supramolecular Chemistry", "Materials Science", "Nanochemistry", "Chemical Thermodynamics",
    "Chemical Engineering", "Catalysis", "Reaction Mechanisms", "Solubility", "Phase Equilibria",
    "Coordination Chemistry", "Crystallography", "Solid State Chemistry", "Computational Chemistry", "Chemical Nomenclature",
    "Molecular Orbitals", "Valence Bond Theory", "Electron Configuration", "Lewis Structures", "VSEPR Theory",
    "Molecular Polarity", "Hybridization", "Sigma and Pi Bonds", "Ionic Bonds", "Covalent Bonds",
    "Metallic Bonds", "Van der Waals Forces", "Hydrogen Bonding", "Dipole-Dipole Interactions", "London Dispersion Forces",
    "Colligative Properties", "Osmosis and Diffusion", "Electrophilic Addition", "Nucleophilic Substitution", "Elimination Reactions",
    "Aromaticity", "Alkanes, Alkenes, Alkynes", "Functional Groups", "Stereochemistry", "Carbohydrates",
    "Proteins", "Nucleic Acids", "Lipids", "Enzyme Kinetics", "Metabolism",
    "Vitamins and Minerals", "Toxicology", "Pharmacology", "Medicinal Chemistry", "Drug Design",
    "Chemoinformatics", "Petrochemistry", "Agrochemistry", "Food Chemistry", "Cosmetic Chemistry",
    "Atmospheric Chemistry", "Ocean Chemistry", "Soil Chemistry", "Water Chemistry", "Fire Chemistry",
    "Color Chemistry", "Photochemistry", "Electrolytes", "Non-covalent Interactions", "Chemical Safety",
    "Radiochemistry", "Actinides", "Lanthanides", "Transition Metals", "Rare Earth Elements",
    "Cell Theory", "Evolution", "Genetics", "Homeostasis", "Ecology",
    "Photosynthesis", "Cellular Respiration", "Molecular Biology", "Biotechnology", "Microbiology",
    "Immunology", "Neurobiology", "Developmental Biology", "Plant Biology", "Animal Physiology",
    "Population Biology", "Conservation Biology", "Behavioral Biology", "Bioinformatics", "Evolutionary Biology",
    "Genomics", "Proteomics", "Metabolomics", "Structural Biology", "Pharmacology",
    "Environmental Biology", "Marine Biology", "Zoology", "Botany", "Mycology",
    "Parasitology", "Virology", "Bacteriology", "Endocrinology", "Reproductive Biology",
    "Taxonomy", "Biophysics", "Biochemistry", "Cellular Anatomy", "Systematics",
    "Paleobiology", "Biogeography", "Epidemiology", "Pathology", "Entomology",
    "Herpetology", "Ornithology", "Ichthyology", "Mammalogy", "Primatology",
    "Ecotoxicology", "Aquatic Biology", "Soil Biology", "Agronomy", "Horticulture",
    "Forestry", "Bioclimatology", "Paleontology", "Chronobiology", "Gerontology",
    "Cryobiology", "Biomechanics", "Biomimetics", "Synthetic Biology", "Systems Biology",
    "Astrobiology", "Nanobiology", "Computational Biology", "Functional Genomics", "Transcriptomics",
    "Phylogenetics", "Molecular Genetics", "Population Genetics", "Conservation Genetics", "Quantitative Genetics",
    "Molecular Pathogenesis", "Cancer Biology", "Neuroscience", "Cardiovascular Biology", "Pulmonary Biology",
    "Gastrointestinal Biology", "Renal Biology", "Musculoskeletal Biology", "Dermatological Biology", "Ophthalmology Biology",
    "Otology Biology", "Immunopathology", "Microbial Genetics", "Plant Pathology", "Wildlife Biology",
    "Human Biology", "Medical Biology", "Veterinary Biology", "Ethnobiology", "Paleoanthropology",
    "Cognitive Biology", "Psychobiology", "Sociobiology", "Bioethics", "Biostatistics"
]
search_terms.reverse()
"""

# Dataset 6
"""
search_terms = [
    "New York", "Los Angeles", "Chicago", "Houston", "Phoenix",
    "Philadelphia", "San Antonio", "San Diego", "Dallas", "San Jose",
    "Austin", "Jacksonville", "Fort Worth", "Columbus", "Charlotte",
    "San Francisco", "Indianapolis", "Seattle", "Denver", "Washington",
    "Boston", "El Paso", "Detroit", "Nashville", "Portland",
    "Memphis", "Oklahoma City", "Las Vegas", "Louisville", "Baltimore",
    "Milwaukee", "Albuquerque", "Tucson", "Fresno", "Mesa",
    "Sacramento", "Atlanta", "Kansas City", "Colorado Springs", "Miami",
    "Raleigh", "Omaha", "Long Beach", "Virginia Beach", "Oakland",
    "Minneapolis", "Tulsa", "Arlington", "Tampa", "New Orleans",
    "Wichita", "Cleveland", "Bakersfield", "Aurora", "Anaheim",
    "Honolulu", "Santa Ana", "Riverside", "Corpus Christi", "Lexington",
    "Stockton", "Henderson", "Saint Paul", "St. Louis", "Cincinnati",
    "Pittsburgh", "Greensboro", "Anchorage", "Plano", "Lincoln",
    "Orlando", "Irvine", "Newark", "Toledo", "Durham",
    "Chula Vista", "Fort Wayne", "Jersey City", "St. Petersburg", "Laredo",
    "Madison", "Chandler", "Buffalo", "Lubbock", "Scottsdale",
    "Reno", "Glendale", "Gilbert", "Winston–Salem", "North Las Vegas",
    "Norfolk", "Chesapeake", "Garland", "Irving", "Hialeah",
    "London", "Edinburgh", "Manchester", "Birmingham", "Glasgow",
    "Liverpool", "Bristol", "Oxford", "Cambridge", "Cardiff",
    "Brighton", "Newcastle", "Leeds", "Belfast", "Nottingham",
    "Sheffield", "Leicester", "Coventry", "Bradford", "Southampton",
    "Stoke-on-Trent", "Derby", "Sunderland", "Bath", "Lincoln",
    "Exeter", "Norwich", "Plymouth", "Lancaster", "Newport",
    "Preston", "Swansea", "Salford", "Aberdeen", "Westminster",
    "Portsmouth", "York", "Peterborough", "Dundee", "Lancaster",
    "Oxford", "Wolverhampton", "St Albans", "Chester", "Swindon",
    "Reading", "Blackburn", "Worcester", "Newcastle under Lyme", "Bolton",
    "Bournemouth", "Norwich", "Maidstone", "Chelmsford", "Cambridge",
    "Doncaster", "Dundee", "Wolverhampton", "Southampton", "Swansea",
    "Plymouth", "Luton", "Farnborough", "Medway", "Worthing",
    "Ipswich", "Middlesbrough", "Sunderland", "Colchester", "Crawley",
    "Crewe", "Darlington", "Eastbourne", "Exeter", "Gloucester",
    "Guildford", "Hamilton", "Hastings", "Hemel Hempstead", "Hereford",
    "High Wycombe", "Huddersfield", "Hull", "Inverness", "Ipswich",
    "Kilmarnock", "Kingston upon Thames", "Lancaster", "Leeds", "Leicester",
    "Lichfield", "Lincoln", "Lisburn", "Liverpool", "Livingston",
    "Llandudno", "Loughborough", "Lowestoft", "Luton", "Macclesfield",
    "Sydney", "Melbourne", "Brisbane", "Perth", "Adelaide",
    "Gold Coast", "Canberra", "Newcastle", "Wollongong", "Logan City",
    "Geelong", "Hobart", "Townsville", "Cairns", "Darwin",
    "Toowoomba", "Ballarat", "Bendigo", "Albury", "Launceston",
    "Mackay", "Rockhampton", "Bunbury", "Bundaberg", "Coffs Harbour",
    "Wagga Wagga", "Hervey Bay", "Mildura", "Port Macquarie", "Tamworth",
    "Orange", "Dubbo", "Geraldton", "Nowra", "Bathurst",
    "Warrnambool", "Lismore", "Gladstone", "Alice Springs", "Mount Gambier",
    "Kalgoorlie", "Taree", "Traralgon", "Orange", "Bowral",
    "Busselton", "Kalgoorlie", "Albany", "Warragul", "Devonport",
    "Lismore", "Maryborough", "Broken Hill", "Taree", "Ballina",
    "Goulburn", "Armidale", "Gympie", "Mount Isa", "Launceston",
    "Burnie", "Murray Bridge", "Mount Barker", "Victor Harbor", "Whyalla",
    "Cessnock", "Hobart", "Geelong", "Townsville", "Cairns",
    "Toowoomba", "Mandurah", "Port Hedland", "Emerald", "Broome",
    "Karratha", "Griffith", "Kingston", "Rockingham", "Bunbury",
    "Horsham", "Port Lincoln", "Warwick", "Kempsey", "Portland",
    "Grafton", "Katherine", "Bairnsdale", "Sale", "Muswellbrook",
    "Parkes", "Lithgow", "Singleton", "Port Pirie", "Campbelltown",
    "Toronto", "Montreal", "Vancouver", "Calgary", "Edmonton",
    "Ottawa", "Winnipeg", "Quebec City", "Hamilton", "Kitchener",
    "London", "Victoria", "Halifax", "Oshawa", "Windsor",
    "Saskatoon", "St. Catharines", "Regina", "St. John’s", "Kelowna",
    "Barrie", "Sherbrooke", "Guelph", "Abbotsford", "Kingston",
    "Kanata", "Trois-Rivières", "Moncton", "Chicoutimi", "Milton",
    "Red Deer", "Brantford", "Thunder Bay", "White Rock", "Nanaimo",
    "Sudbury", "Lethbridge", "Saint-Jean-sur-Richelieu", "Peterborough", "Kamloops",
    "Saint-Jérôme", "Chilliwack", "Sarnia", "Châteauguay", "Drummondville",
    "Belleville", "Fort McMurray", "Sault Ste. Marie", "Prince George", "Medicine Hat",
    "Welland", "Grande Prairie", "Airdrie", "Granby", "Fredericton",
    "Saint John", "Beloeil", "North Bay", "Saint-Hyacinthe", "Brandon",
    "Vernon", "New Westminster", "Woodstock", "Georgetown", "St. Thomas",
    "Rocky Mountain House", "Lloydminster", "Orillia", "Stratford", "Orangeville",
    "Cape Breton-Sydney", "Courtenay", "Leduc", "Timmins", "Quesnel",
    "Brooks", "Fort St. John", "Cranbrook", "Squamish", "Saint-Georges",
    "Clarington", "Rimouski", "Laval", "Marieville", "Penticton",
    "St. Albert", "Sherwood Park", "Lévis", "Saguenay", "Trois-Rivières",
    "Lakeshore", "Kelowna", "Cambridge", "Whitby", "Gatineau",
    "Langley", "Ajax", "Prince Albert", "Pickering", "Oakville"
]
"""

search_terms = [
    "IKEA", "West Elm", "Restoration Hardware", "Ashley Furniture", "Raymour & Flanigan",
    "Bernhardt", "La-Z-Boy", "Ethan Allen", "Crate & Barrel", "Pottery Barn",
    "Bassett Furniture", "Wayfair", "CB2", "Room & Board", "Arhaus",
    "Herman Miller", "Knoll", "Ligne Roset", "B&B Italia", "Natuzzi",
    "Stickley", "Thomasville", "Haverty's Furniture", "Joybird", "American Signature",
    "Mitchell Gold + Bob Williams", "Roche Bobois", "Flexsteel", "Magnolia Home by Joanna Gaines", "Z Gallerie",
    "Scandinavian Designs", "RH Modern", "Casper", "Levin Furniture", "Kartell",
    "Floyd", "Article", "AllModern", "Blu Dot", "BoConcept",
    "DwellStudio", "EQ3", "Furniture Row", "Gus* Modern", "Hooker Furniture",
    "Joss & Main", "Klaussner", "Lexington Furniture", "Lovesac", "Modloft",
    "Mor Furniture for Less", "Nadeau", "One Kings Lane", "Overstock", "Pier 1 Imports",
    "Poliform", "Roomstogo", "Serena & Lily", "Simmons", "Slumberland Furniture",
    "Steelcase", "Surya", "The Container Store", "Tuft & Needle", "Universal Furniture",
    "Vitra", "Walker Edison", "Williams-Sonoma", "World Market", "YLiving",
    "Zuri Furniture", "Apt2B", "Birch Lane", "Camerich", "Design Within Reach",
    "Elite Modern", "FLOS", "Frontgate", "Greenington", "Hayneedle",
    "Industry West", "Jonathan Adler", "Kelly Wearstler", "Lulu and Georgia", "Moooi",
    "Muuto", "Nuevo", "Oly Studio", "Perigold", "Ralph Lauren Home",
    "Resource Furniture", "Safavieh", "Scavolini", "Thayer Coggin", "The Inside",
    "Tom Dixon", "TrueModern", "Varier", "Westnofa", "Artek",
    "Bolia", "Calligaris", "Cassina", "De La Espada", "Emeco",
    "Foscarini", "Gubi", "HAY", "Innermost", "Janus et Cie",
    "Kartell", "Loll Designs", "Magis", "Minotti", "Montis",
    "Natuzzi Italia", "Porada", "Republic of Fritz Hansen", "Secto Design", "Skagerak",
    "Sofas & Stuff", "Stressless", "Teknion", "USM Modular Furniture", "Vipp",
    "Vitra", "Walter Knoll", "We Do Wood", "Whiteline Modern Living", "Zanotta",
    "AICO (Amini Innovation Corp)", "Bradington-Young", "Caracole", "Christopher Guy", "Councill",
    "Drexel Heritage", "Fairfield Chair Company", "Four Hands", "Hancock & Moore", "Henkel Harris",
    "Henredon", "Hooker Furniture", "Howard Miller", "Jaipur Living", "James Martin Furniture",
    "Jessica Charles", "John Richard", "Jonathan Charles", "Kincaid Furniture", "Maitland-Smith",
    "Palecek", "Palliser Furniture", "Precedent", "Sam Moore", "Sherrill Furniture",
    "Stanley Furniture", "Summer Classics", "Surya", "Theodore Alexander", "Tommy Bahama Home",
    "Universal Furniture", "Uttermost", "Vanguard Furniture", "Visual Comfort", "Wildwood Lamps",
    "Younger Furniture", "Zuo Modern", "Acme Furniture", "Alf Italia", "Ambella Home Collection",
    "American Drew", "Amisco", "Broyhill", "Canadel", "Capel Rugs",
    "Charleston Forge", "Coaster Furniture", "Craftmaster Furniture", "Cyan Design", "Dalyn Rug Company",
    "Eastern Accents", "Elk Home", "Fairmont Designs", "Global Views", "Hillsdale Furniture",
    "Homelegance", "Interlude Home", "Jamie Young Company", "John Boos & Co.", "Kaleen Rugs",
    "Liberty Furniture", "Loloi Rugs", "Malouf", "Modus Furniture International", "Nourison",
    "Phillips Collection", "Pulaski Furniture", "Quoizel", "Riverside Furniture", "Safco Products",
    "Sauder", "Schnadig", "Serta", "Signature Design by Ashley", "Somerton Dwelling",
    "South Shore Furniture", "Sphinx by Oriental Weavers", "Stein World", "Steve Silver Co.", "Sunny Designs",
    "Sylvan Furniture", "Tempur-Pedic", "Tropitone", "Universal Lighting and Decor", "Vaughan-Bassett",
    "Wesley Allen", "Whittier Wood Products", "Winners Only", "Wynwood Furniture", "Z-Line Designs"
]

# %%
lock = threading.Lock()
start_time = time.time()
starting_videos = str(len(existing_videos))

print("Starting with " + starting_videos + " videos")
print("Starting at", start_time)
print("\n")

global searches_done
searches_done = False

global _SEARCH_QUEUE
_SEARCH_QUEUE += len(search_terms)

# Starting the summary thread
summary_thread = threading.Thread(target=print_summary_periodically, args=(5, 12))
summary_thread.start()

futures = []
with ThreadPoolExecutor(max_workers = 128) as executor:
    for search_term in search_terms:
        time.sleep(random.uniform(0, 20))
        futures.append(executor.submit(perform_search, search_term))

for future in as_completed(futures):
    try:
        result = future.result()
    except Exception as exc:
        print(f'Top-level thread generated an exception: {exc}')

with lock:
    searches_done = True

summary_thread.join()

end_time = time.time()
ending_videos = str(len(existing_videos))
print("DONE", int(time.time()), "| Queued:", _QUEUED, "| Working:", _WORKING, "| Downloading:", _DOWNLOADING, "| Downloaded:", _DOWNLOADED, "| Skipped:", _SKIPPED, "| Exceptioned:", _EXCEPTIONED)
print("\n")
print("Started with " + str(starting_videos) + " videos")
print("Started at", start_time)
print("Ending with " + str(ending_videos) + " videos")
print("Ending at", end_time)
# Out:
# Starting with 132936 videos
# Starting at 1708645258.114762
#
#
# 1 1708645263 | Queued: 0 | Working: 0 | Downloading: 0 | Good: 0 | Skip: 0 | Error: 0 | Term Queue: 220 | Term Working: 0
# 2 1708645268 | Queued: 0 | Working: 0 | Downloading: 0 | Good: 0 | Skip: 0 | Error: 0 | Term Queue: 220 | Term Working: 0
# 83 1708645680 | Queued: 131 | Working: 6 | Downloading: 4 | Good: 331 | Skip: 3450 | Error: 19 | Term Queue: 178 | Term Working: 7
# STARTING SEARCH TERM Furniture Row
# STARTING SEARCH TERM Gus* Modern
# 84 1708645686 | Queued: 125 | Working: 7 | Downloading: 2 | Good: 337 | Skip: 3546 | Error: 19 | Term Queue: 176 | Term Working: 9
# K9W1focD278 Stopping download because of Exception K9W1focD278 is age restricted, and can't be accessed without logging in.
# COMPLETED SEARCH TERM Blu Dot | 32 seconds | 82 results | 7 downloaded
# 85 1708645691 | Queued: 119 | Working: 6 | Downloading: 3 | Good: 341 | Skip: 3548 | Error: 20 | Term Queue: 176 | Term Working: 8
# vKjpDrm-v6E Stopping download because of Exception vKjpDrm-v6E is age restricted, and can't be accessed without logging in.
# 86 1708645696 | Queued: 81 | Working: 6 | Downloading: 2 | Good: 347 | Skip: 3579 | Error: 21 | Term Queue: 176 | Term Working: 8
# 9Dyn9AuANwU Stopping download because of Exception 9Dyn9AuANwU is age restricted, and can't be accessed without logging in.
# qpBGaSMYBAs Stopping download because of Exception qpBGaSMYBAs is age restricted, and can't be accessed without logging in.
# 87 1708645701 | Queued: 198 | Working: 8 | Downloading: 3 | Good: 351 | Skip: 3642 | Error: 23 | Term Queue: 176 | Term Working: 8
# u0WwiUEviegSTARTING SEARCH TERM Hooker Furniture
#  Stopping download because of Exception u0WwiUEvieg is age restricted, and can't be accessed without logging in.
# COMPLETED SEARCH TERM EQ3 | 18 seconds | 97 results | 3 downloaded
# -ZeviuSxYB8 Stopping download because of Exception -ZeviuSxYB8 is age restricted, and can't be accessed without logging in.
# 88 1708645706 | Queued: 183 | Working: 7 | Downloading: 3 | Good: 355 | Skip: 3652 | Error: 25 | Term Queue: 175 | Term Working: 8
# IMDG_TbF6Lg Stopping download because of Exception IMDG_TbF6Lg is age restricted, and can't be accessed without logging in.
# 89 1708645711 | Queued: 153 | Working: 7 | Downloading: 3 | Good: 360 | Skip: 3676 | Error: 26 | Term Queue: 175 | Term Working: 8
# COMPLETED SEARCH TERM AllModern | 72 seconds | 92 results | 11 downloaded
# STARTING SEARCH TERM Joss & Main
# 90 1708645716 | Queued: 136 | Working: 7 | Downloading: 4 | Good: 365 | Skip: 3787 | Error: 26 | Term Queue: 174 | Term Working: 8
# COMPLETED SEARCH TERM Casper | 125 seconds | 100 results | 19 downloaded
# COMPLETED SEARCH TERM Hooker Furniture | 6 seconds | 99 results | 1 downloaded
# COMPLETED SEARCH TERM Furniture Row | 24 seconds | 90 results | 4 downloaded
# 91 1708645721 | Queued: 85 | Working: 4 | Downloading: 2 | Good: 372 | Skip: 3834 | Error: 26 | Term Queue: 174 | Term Working: 5
# STARTING SEARCH TERM Klaussner
# 92 1708645726 | Queued: 72 | Working: 4 | Downloading: 2 | Good: 376 | Skip: 3843 | Error: 26 | Term Queue: 173 | Term Working: 6
# STARTING SEARCH TERM Lexington Furniture
# 3y1Jiy_qC5U Stopping download because of Exception 3y1Jiy_qC5U is age restricted, and can't be accessed without logging in.
# 164 1708646094 | Queued: 124 | Working: 5 | Downloading: 4 | Good: 692 | Skip: 6317 | Error: 41 | Term Queue: 144 | Term Working: 6
# COMPLETED SEARCH TERM Camerich | 24 seconds | 82 results | 5 downloaded
# STARTING SEARCH TERM FLOS
# 165 1708646099 | Queued: 82 | Working: 4 | Downloading: 2 | Good: 698 | Skip: 6354 | Error: 41 | Term Queue: 143 | Term Working: 6
# 166 1708646104 | Queued: 94 | Working: 5 | Downloading: 3 | Good: 702 | Skip: 6430 | Error: 41 | Term Queue: 143 | Term Working: 6
# COMPLETED SEARCH TERM YLiving | 91 seconds | 88 results | 21 downloaded
# TpdYSdqUB8A Stopping download because of Exception TpdYSdqUB8A is age restricted, and can't be accessed without logging in.
# 167 1708646109 | Queued: 152 | Working: 5 | Downloading: 2 | Good: 707 | Skip: 6464 | Error: 42 | Term Queue: 143 | Term Working: 5
# STARTING SEARCH TERM Frontgate
# 168 1708646114 | Queued: 107 | Working: 5 | Downloading: 4 | Good: 711 | Skip: 6505 | Error: 42 | Term Queue: 142 | Term Working: 6
# 169 1708646120 | Queued: 101 | Working: 5 | Downloading: 4 | Good: 715 | Skip: 6507 | Error: 42 | Term Queue: 142 | Term Working: 6
# xmSGZMrkQUs Stopping download because of Exception xmSGZMrkQUs is age restricted, and can't be accessed without logging in.
# COMPLETED SEARCH TERM Elite Modern | 19 seconds | 93 results | 3 downloaded
# COMPLETED SEARCH TERM Apt2B | 81 seconds | 99 results | 19 downloaded
# 170 1708646125 | Queued: 76 | Working: 3 | Downloading: 3 | Good: 721 | Skip: 6527 | Error: 43 | Term Queue: 142 | Term Working: 4
# STARTING SEARCH TERM Greenington
# 171 1708646130 | Queued: 57 | Working: 4 | Downloading: 2 | Good: 726 | Skip: 6638 | Error: 43 | Term Queue: 141 | Term Working: 5
# DNoIMuCOdj8 Stopping download because of Exception DNoIMuCOdj8 is age restricted, and can't be accessed without logging in.
# lUn65T3bImY Stopping download because of Exception lUn65T3bImY is age restricted, and can't be accessed without logging in.
# 172 1708646135 | Queued: 42 | Working: 4 | Downloading: 2 | Good: 730 | Skip: 6647 | Error: 45 | Term Queue: 141 | Term Working: 5
# LLUjaJlB9Dc Stopping download because of Exception LLUjaJlB9Dc is age restricted, and can't be accessed without logging in.
# STARTING SEARCH TERM Hayneedle
# Xmz3sS429CQ Stopping download because of Exception Xmz3sS429CQ is age restricted, and can't be accessed without logging in.
# 173 1708646140 | Queued: 80 | Working: 5 | Downloading: 3 | Good: 733 | Skip: 6695 | Error: 47 | Term Queue: 140 | Term Working: 6
# 174 1708646145 | Queued: 59 | Working: 5 | Downloading: 4 | Good: 738 | Skip: 6711 | Error: 47 | Term Queue: 140 | Term Working: 6
# brBL6hVo1v8 Stopping download because of Exception brBL6hVo1v8 is age restricted, and can't be accessed without logging in.
# COMPLETED SEARCH TERM FLOS | 43 seconds | 98 results | 9 downloaded
# 175 1708646150 | Queued: 106 | Working: 5 | Downloading: 3 | Good: 743 | Skip: 6752 | Error: 48 | Term Queue: 140 | Term Working: 5
# 189 1708646222 | Queued: 78 | Working: 4 | Downloading: 1 | Good: 804 | Skip: 7180 | Error: 52 | Term Queue: 134 | Term Working: 5
# COMPLETED SEARCH TERM Greenington | 85 seconds | 92 results | 11 downloaded
# 190 1708646227 | Queued: 116 | Working: 4 | Downloading: 2 | Good: 808 | Skip: 7237 | Error: 52 | Term Queue: 134 | Term Working: 4
# STARTING SEARCH TERM Nuevo
# STARTING SEARCH TERM Oly Studio
# B-g3m_SJlbE Stopping download because of Exception B-g3m_SJlbE is age restricted, and can't be accessed without logging in.
# 191 1708646232 | Queued: 96 | Working: 4 | Downloading: 3 | Good: 812 | Skip: 7252 | Error: 53 | Term Queue: 132 | Term Working: 6
# 0RJZhWD8UxQ Stopping download because of Exception 0RJZhWD8UxQ is age restricted, and can't be accessed without logging in.
# 192 1708646237 | Queued: 146 | Working: 5 | Downloading: 1 | Good: 817 | Skip: 7291 | Error: 54 | Term Queue: 132 | Term Working: 6
# uQpi4Xufg9s Stopping download because of Exception uQpi4Xufg9s is age restricted, and can't be accessed without logging in.
# 193 1708646243 | Queued: 191 | Working: 6 | Downloading: 2 | Good: 821 | Skip: 7326 | Error: 55 | Term Queue: 132 | Term Working: 6
# COMPLETED SEARCH TERM Moooi | 42 seconds | 94 results | 10 downloaded
# COMPLETED SEARCH TERM Muuto | 21 seconds | 99 results | 5 downloaded
# 194 1708646248 | Queued: 160 | Working: 4 | Downloading: 1 | Good: 827 | Skip: 7353 | Error: 55 | Term Queue: 132 | Term Working: 4
# STARTING SEARCH TERM Perigold
# STARTING SEARCH TERM Ralph Lauren Home
# VOgcy2jg95Q Stopping download because of Exception VOgcy2jg95Q is age restricted, and can't be accessed without logging in.
# COMPLETED SEARCH TERM Industry West | 87 seconds | 90 results | 17 downloaded
# SWbCKDaq7sU Stopping download because of Exception SWbCKDaq7sU is age restricted, and can't be accessed without logging in.
# 195 1708646253 | Queued: 110 | Working: 3 | Downloading: 2 | Good: 829 | Skip: 7400 | Error: 57 | Term Queue: 130 | Term Working: 5
# TBHrpgIK8PM Stopping download because of Exception TBHrpgIK8PM is age restricted, and can't be accessed without logging in.
# 196 1708646258 | Queued: 174 | Working: 4 | Downloading: 2 | Good: 833 | Skip: 7423 | Error: 58 | Term Queue: 130 | Term Working: 5
# 197 1708646263 | Queued: 237 | Working: 5 | Downloading: 4 | Good: 836 | Skip: 7450 | Error: 58 | Term Queue: 130 | Term Working: 5
# STARTING SEARCH TERM Resource Furniture
# 198 1708646268 | Queued: 219 | Working: 5 | Downloading: 4 | Good: 840 | Skip: 7464 | Error: 58 | Term Queue: 129 | Term Working: 6
# COMPLETED SEARCH TERM Lulu and Georgia | 79 seconds | 94 results | 16 downloaded
# 199 1708646273 | Queued: 173 | Working: 4 | Downloading: 2 | Good: 847 | Skip: 7504 | Error: 58 | Term Queue: 129 | Term Working: 5
# kODNd9Oj6_4 Stopping download because of Exception kODNd9Oj6_4 is age restricted, and can't be accessed without logging in.
# c6BskDpm5Po Stopping download because of Exception c6BskDpm5Po is age restricted, and can't be accessed without logging in.
# STARTING SEARCH TERM Safavieh
# 200 1708646279 | Queued: 162 | Working: 5 | Downloading: 2 | Good: 852 | Skip: 7591 | Error: 60 | Term Queue: 128 | Term Working: 6
# bMPlWL9C1y4 Stopping download because of Exception bMPlWL9C1y4 is age restricted, and can't be accessed without logging in.
# 201 1708646284 | Queued: 147 | Working: 5 | Downloading: 2 | Good: 857 | Skip: 7600 | Error: 61 | Term Queue: 128 | Term Working: 6
# 202 1708646289 | Queued: 89 | Working: 5 | Downloading: 1 | Good: 863 | Skip: 7652 | Error: 61 | Term Queue: 128 | Term Working: 6
# FFZs5-URVNc Stopping download because of Exception FFZs5-URVNc is age restricted, and can't be accessed without logging in.
# COMPLETED SEARCH TERM Resource Furniture | 18 seconds | 84 results | 4 downloaded
# 203 1708646294 | Queued: 158 | Working: 5 | Downloading: 2 | Good: 867 | Skip: 7677 | Error: 62 | Term Queue: 128 | Term Working: 5
# STARTING SEARCH TERM Scavolini
# COMPLETED SEARCH TERM Ralph Lauren Home | 37 seconds | 94 results | 6 downloaded
# JRBGZSzZvhA Stopping download because of Exception JRBGZSzZvhA is age restricted, and can't be accessed without logging in.
# STARTING SEARCH TERM Thayer Coggin
# 204 1708646299 | Queued: 98 | Working: 4 | Downloading: 1 | Good: 872 | Skip: 7732 | Error: 63 | Term Queue: 126 | Term Working: 6
# x0beBXgY89w Stopping download because of Exception x0beBXgY89w is streaming live and cannot be loaded
# 205 1708646304 | Queued: 113 | Working: 5 | Downloading: 2 | Good: 876 | Skip: 7809 | Error: 64 | Term Queue: 126 | Term Working: 6
# KlklVUp4b7I Stopping download because of Exception KlklVUp4b7I is age restricted, and can't be accessed without logging in.
# ZyGgOSXQ6uU Stopping download because of Exception ZyGgOSXQ6uU is age restricted, and can't be accessed without logging in.
# 206 1708646309 | Queued: 164 | Working: 6 | Downloading: 3 | Good: 880 | Skip: 7850 | Error: 66 | Term Queue: 126 | Term Working: 6
# STARTING SEARCH TERM The Inside
# 207 1708646314 | Queued: 155 | Working: 6 | Downloading: 2 | Good: 886 | Skip: 7853 | Error: 66 | Term Queue: 125 | Term Working: 7
# 208 1708646319 | Queued: 145 | Working: 6 | Downloading: 3 | Good: 890 | Skip: 7859 | Error: 66 | Term Queue: 125 | Term Working: 7
# 209 1708646325 | Queued: 139 | Working: 6 | Downloading: 2 | Good: 896 | Skip: 7859 | Error: 66 | Term Queue: 125 | Term Working: 7
# COMPLETED SEARCH TERM Scavolini | 21 seconds | 98 results | 3 downloaded
# COMPLETED SEARCH TERM Nuevo | 91 seconds | 96 results | 17 downloaded
# 210 1708646330 | Queued: 184 | Working: 5 | Downloading: 1 | Good: 903 | Skip: 7904 | Error: 66 | Term Queue: 125 | Term Working: 5
# STARTING SEARCH TERM Tom Dixon
# isYKLOh0O_I Stopping download because of Exception isYKLOh0O_I is age restricted, and can't be accessed without logging in.
# 211 1708646335 | Queued: 171 | Working: 5 | Downloading: 2 | Good: 907 | Skip: 7912 | Error: 67 | Term Queue: 124 | Term Working: 6
# STARTING SEARCH TERM TrueModern
| Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2252 1708656629 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2253 1708656634 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2254 1708656639 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2255 1708656644 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2256 1708656649 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2257 1708656654 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2258 1708656659 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2259 1708656664 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2260 1708656669 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2261 1708656674 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2262 1708656679 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2263 1708656684 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2264 1708656689 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2265 1708656694 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2266 1708656699 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2267 1708656704 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2268 1708656709 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2269 1708656714 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2270 1708656719 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2271 1708656724 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2272 1708656729 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2273 1708656734 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2274 1708656739 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2275 1708656744 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2276 1708656749 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2277 1708656754 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2278 1708656759 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2279 1708656764 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2280 1708656769 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2281 1708656774 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2282 1708656779 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2283 1708656784 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2284 1708656789 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2285 1708656794 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2286 1708656799 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2287 1708656804 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2288 1708656809 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2289 1708656814 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2290 1708656819 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2291 1708656824 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2292 1708656829 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2293 1708656834 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2294 1708656839 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2295 1708656844 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2296 1708656849 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2297 1708656854 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2298 1708656859 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2299 1708656864 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2300 1708656869 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2301 1708656874 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2302 1708656879 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2303 1708656884 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2304 1708656889 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2305 1708656894 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2306 1708656899 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2307 1708656904 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2308 1708656909 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2309 1708656914 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2310 1708656919 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2311 1708656924 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2312 1708656929 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2313 1708656934 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2314 1708656939 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2315 1708656944 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2316 1708656949 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2317 1708656954 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2318 1708656959 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2319 1708656964 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2320 1708656969 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2321 1708656974 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2322 1708656980 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5
# 2323 1708656985 | Queued: 165 | Working: 5 | Downloading: 2 | Good: 3510 | Skip: 16728 | Error: 188 | Term Queue: 0 | Term Working: 5

# %%
# import glob
# import os
# from moviepy.editor import AudioFileClip

# def static_analysis(location):
#     folders = {x for x in os.listdir(location)}
#     print("Videos crawled:", len(folders))
#     print()
    
#     has_audio = 0 
#     has_at_least_one_transcript = 0
    
#     total_bytes = 0
#     total_length = 0
#     transcripts = {}   

#     for folder in folders[:500]:
#         if not os.path.exists(location + folder + "/audio.mp4"):
#             continue
#         total_bytes += os.path.getsize(location + folder + "/audio.mp4")
#         if total_bytes == 0:
#             continue
#         has_audio += 1
#         with AudioFileClip(location + folder + "/audio.mp4") as audio:
#             total_length += audio.duration
#         has_transcript = False
#         for file in os.listdir(location + folder):
#             if ".json" in file:
#                 has_transcript = True
#                 language = file.replace("caption-", "").replace(".json", "")
#                 if language not in transcripts:
#                     transcripts[language] = 0
#                 transcripts[language] += 1
#         if has_transcript:
#             has_at_least_one_transcript += 1
        
#     print("Downloaded mp4 Files:", has_audio)
#     print("Total mp4 Audio Duration (seconds):", int(total_length))
#     print("Total mp4 Filesize (bytes):", total_bytes)
#     print()
    
#     transcripts = sorted(transcripts.items(), key=lambda item: item[1], reverse=True)
#     print("Has at least one transcript:", has_at_least_one_transcript)
#     for language, count in transcripts:
#         print("Transcripts of language", language + ":", count)

# static_analysis("dataset-4/")
# Out:
# Videos crawled: 5367
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 47
#      44     for language, count in transcripts:
#      45         print("Transcripts of language", language + ":", count)
# ---> 47 static_analysis("dataset-3/")
#
# Cell In[10], line 17, in static_analysis(location)
#      14 total_length = 0
#      15 transcripts = {}
# ---> 17 for folder in folders[:500]:
#      18     if not os.path.exists(location + folder + "/audio.mp4"):
#      19         continue
#
# TypeError: 'set' object is not subscriptable
