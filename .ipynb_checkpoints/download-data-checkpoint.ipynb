# %%
import os
import json

def attempt_download(yt_obj, existing_videos, location = "dataset-5/"):
    vid = yt_obj.video_id
    print(vid, "attempt_download called")
    if vid in existing_videos:
        print(vid, "Skipping, found existing folder.")
        return False
    
    os.makedirs(location + vid)
    try:
        stream = yt_obj.streams.get_by_itag(139)
    except Exception as e:
        print(vid, "Stopping download because of Exception", e)
        return False
    stream.download(output_path = location + vid + "/", filename = "audio.mp4")
    print(vid, "Audio downloaded")
    
    print(vid, "Found captions for", list(yt_obj.captions.keys()))
    for caption in yt_obj.captions:
        if "en" in caption.code:
            a_en_caption = caption.json_captions
            json.dump(a_en_caption, open(location + vid + "/caption-" + caption.code + ".json", 'w'))
            print(vid, "Downloaded", caption.code, "captions")
    
    existing_videos.add(yt_obj.video_id)

# %%
from pytube import Search

def deep_search(search_term, existing_videos, depth = 10):
    print("Search", search_term, "Performing search at depth", depth)
    search = Search(search_term)
    search.results
    for _ in range(depth - 1):
        search.get_next_results()
        
    print("Search", search_term, "Found", len(search.results), "videos")
        
    for yt in search.results:
        attempt_download(yt, existing_videos)

# %%
from concurrent.futures import ThreadPoolExecutor
import time

directories = ["dataset/", "dataset-2/", "dataset-3/", "dataset-4/"]
existing_videos = {file for directory in directories for file in os.listdir(directory)}


start_time = time.time()
starting_videos = str(len(existing_videos))

print("Starting with " + starting_videos + " videos")
print("Starting at", start_time)

"""
search_terms = [
    "Joe Biden", "Kamala Harris", "Donald Trump", "Mike Pence", "Ron DeSantis",
    "Barack Obama", "Angela Merkel", "Vladimir Putin", "Xi Jinping", "Emmanuel Macron",
    "Narendra Modi", "Jair Bolsonaro", "Justin Trudeau", "Boris Johnson", "Jacinda Ardern",
    "Leonardo DiCaprio", "Meryl Streep", "Denzel Washington", "Tom Hanks", "Jennifer Lawrence",
    "Scarlett Johansson", "Brad Pitt", "Angelina Jolie", "Johnny Depp", "Nicole Kidman",
    "Beyoncé", "Taylor Swift", "Kanye West", "Rihanna", "Jay-Z",
    "Drake", "Adele", "Ed Sheeran", "Justin Bieber", "Lady Gaga",
    "Cristiano Ronaldo", "Lionel Messi", "LeBron James", "Serena Williams", "Roger Federer",
    "Usain Bolt", "Michael Phelps", "Simone Biles", "Novak Djokovic", "Tiger Woods",
    "Elon Musk", "Jeff Bezos", "Bill Gates", "Mark Zuckerberg", "Warren Buffett",
    "Tim Cook", "Larry Page", "Sergey Brin", "Jack Ma", "Mukesh Ambani",
    "Oprah Winfrey", "Ellen DeGeneres", "Kim Kardashian", "Kylie Jenner", "Greta Thunberg",
    "Malala Yousafzai", "Dalai Lama", "Pope Francis", "Donald Glover", "Dave Chappelle",
    "Stephen King", "J.K. Rowling", "George R.R. Martin", "Neil Gaiman", "Margaret Atwood",
    "Steven Spielberg", "Christopher Nolan", "Quentin Tarantino", "Martin Scorsese", "Wes Anderson",
    "Ariana Grande", "Snoop Dogg", "Eminem", "Shakira", "Katy Perry",
    "Dwayne Johnson", "Chris Hemsworth", "Robert Downey Jr.", "Hugh Jackman", "Ryan Reynolds"
]
"""


"""
search_terms = [
    "Apple", "Microsoft", "Google", "Amazon", "Facebook",
    "Berkshire Hathaway", "Visa", "Johnson & Johnson", "Walmart", "Procter & Gamble",
    "Intel", "Verizon Communications", "AT&T", "Coca-Cola", "Pfizer",
    "Chevron", "Home Depot", "Merck & Co.", "Disney", "Cisco Systems",
    "IBM", "Boeing", "Goldman Sachs", "McDonald's", "3M",
    "Nike", "American Express", "UnitedHealth Group", "ExxonMobil", "General Electric",
    "JP Morgan Chase", "Morgan Stanley", "Tesla", "Netflix", "Adobe Systems",
    "Salesforce", "Oracle", "PayPal", "Qualcomm", "AMD",
    "eBay", "General Motors", "Ford Motor Company", "Delta Air Lines", "United Airlines",
    "Lockheed Martin", "Raytheon Technologies", "Northrop Grumman", "General Dynamics", "Honeywell",
    "Caterpillar", "DuPont", "FedEx", "UPS", "Booz Allen Hamilton",
    "Charles Schwab", "Citigroup", "Bank of America", "Wells Fargo", "Goldman Sachs Group",
    "American Airlines Group", "Southwest Airlines", "Gilead Sciences", "Bristol-Myers Squibb", "Amgen",
    "Biogen", "Celgene", "AbbVie", "Eli Lilly and Company", "Merck",
    "Snap Inc.", "Twitter", "LinkedIn", "Spotify", "Square",
    "Lyft", "Uber Technologies", "Airbnb", "SpaceX", "Palantir Technologies",
    "Stripe", "Robinhood", "Coinbase", "Zoom Video Communications", "Slack Technologies",
    "Dell Technologies", "HP Inc.", "IBM Corporation", "Intel Corporation", "Micron Technology",
    "NVIDIA", "Broadcom Inc.", "Texas Instruments", "Qualtrics", "Snowflake",
    "DoorDash", "Instacart", "Etsy", "Roku", "Pinterest"
]
"""

"""
search_terms = [
    "True Crime Stories", "Startup Founders", "Health and Wellness Tips", "Investing for Beginners", "Science Discoveries",
    "History Mysteries", "Technology Innovations", "Mindfulness and Meditation", "Global News Analysis", "Book Review Series",
    "Comedy Shows", "Film Criticism", "Music Industry Insights", "Sports Commentary", "Fashion Trends",
    "Culinary Arts", "Language Learning", "Travel Adventures", "Parenting Advice", "Personal Finance Strategies",
    "Political Analysis", "Art and Design", "Entrepreneurship Lessons", "Educational Strategies", "Mental Health Support",
    "Fitness Coaching", "Environmental Conservation", "Digital Marketing", "Philosophy and Ethics", "Astronomy and Space",
    "Mythology and Folklore", "Cybersecurity Updates", "Blockchain and Cryptocurrency", "Artificial Intelligence Trends", "Real Estate Investing",
    "Sustainability Practices", "Creative Writing", "Public Speaking Tips", "Career Development", "Classical Music Appreciation",
    "Video Game Reviews", "Comics and Graphic Novels", "Quantum Computing", "Social Media Strategies", "DIY Home Projects",
    "Yoga and Pilates", "Pet Care and Training", "Indie Film Making", "Jazz Music Exploration", "Virtual Reality Experiences"
]"""

"""
search_terms = [
    "TED Talk Artificial Intelligence", "TED Talk Blockchain Technology", "TED Talk Climate Change", "TED Talk Cybersecurity", "TED Talk Data Privacy",
    "TED Talk Digital Health", "TED Talk E-commerce Trends", "TED Talk Future of Work", "TED Talk Genetic Engineering", "TED Talk Green Energy",
    "TED Talk Human Rights", "TED Talk Innovation in Education", "TED Talk Journalism and Media", "TED Talk Leadership and Management", "TED Talk Mental Health",
    "TED Talk Neurotechnology", "TED Talk Online Learning", "TED Talk Pandemic Response", "TED Talk Quantum Computing", "TED Talk Racial Equality",
    "TED Talk Renewable Resources", "TED Talk Space Exploration", "TED Talk Sustainable Living", "TED Talk Technology and Society", "TED Talk Universal Basic Income",
    "TED Talk Virtual Reality", "TED Talk Women in STEM", "TED Talk Xenotransplantation", "TED Talk Youth Activism", "TED Talk Zero Waste Lifestyle",
    "TED Talk Creative Problem Solving", "TED Talk Digital Nomads", "TED Talk Emotional Intelligence", "TED Talk Financial Literacy", "TED Talk Globalization and Trade",
    "TED Talk Health and Nutrition", "TED Talk Immigrant Experiences", "TED Talk Job Automation", "TED Talk Knowledge Sharing", "TED Talk Language Preservation",
    "TED Talk Mindfulness and Meditation", "TED Talk Nature Conservation", "TED Talk Open Source Software", "TED Talk Political Polarization", "TED Talk Quantum Teleportation",
    "TED Talk Refugee Crisis", "TED Talk Social Entrepreneurship", "TED Talk Telemedicine", "TED Talk Urban Planning", "TED Talk Vaccine Development"
]
"""
"""
search_terms = [
    "Khan Academy", "CrashCourse", "TED-Ed", "National Geographic", "SciShow",
    "MinutePhysics", "Vsauce", "CGP Grey", "Veritasium", "SmarterEveryDay",
    "AsapSCIENCE", "Physics Girl", "Numberphile", "Kurzgesagt – In a Nutshell", "BBC Earth",
    "The School of Life", "Big Think", "PBS Space Time", "3Blue1Brown", "BrainCraft",
    "Extra Credits", "Deep Look", "It's Okay To Be Smart", "The Royal Institution", "Practical Engineering",
    "Historia Civilis", "The Art Assignment", "TEDx Talks", "Computerphile", "Seeker",
    "Vsauce2", "Vsauce3", "Wendover Productions", "Real Engineering", "Biographics",
    "SciShow Space", "SciShow Psych", "MinuteEarth", "Tom Scott", "Cody'sLab",
    "Nerdwriter1", "PolyMatter", "Half as Interesting", "TierZoo", "PBS Eons",
    "The Infographics Show", "Overly Sarcastic Productions", "PatrickJMT", "Sixty Symbols", "Geography Now"
]
"""

"""
search_terms = [
    "Unbox Therapy", "Marques Brownlee", "Linus Tech Tips", "Dave Lee", "Jonathan Morrison",
    "Austin Evans", "TechSource", "JerryRigEverything", "CNET", "The Verge",
    "MKBHD", "TechRadar", "Engadget", "TLD Today", "UrAvgConsumer",
    "Flossy Carter", "PhoneBuff", "iJustine", "What's Inside?", "TechSmartt",
    "Mrwhosetheboss", "Pocketnow", "SuperSaf TV", "TechnoBuffalo", "Android Authority",
    "Jenna Ezarik", "Lou Later", "Tech Chap", "MobileTechReview", "EverythingApplePro",
    "TechMeOut", "GadgetMatch", "Erica Griffin", "TheUnlockr", "Zollotech",
    "Booredatwork.com", "TechCrunch", "GSMArena Official", "Geekyranjit", "Tech Spurt",
    "Safwan Ahmedmia (SuperSaf)", "Chris Stuckmann", "Canoopsy", "DetroitBORG", "iGyaan",
    "Krystal Lora", "Matthew Moniz", "Michael Fisher", "Mr Mobile", "Dave2D"
]
"""

"""search_terms = [
    "Tasty", "Binging with Babish", "Rosanna Pansino", "Gordon Ramsay", "Jamie Oliver",
    "King of Random", "5-Minute Crafts", "Bright Side", "ThreadBanger", "Laura in the Kitchen",
    "Yoga With Adriene", "FitnessBlender", "Bob Ross", "Adam Savage’s Tested", "Anne Reardon - How To Cook That",
    "Clean My Space", "Garden Answer", "Home Repair Tutor", "This Old House", "Man Sewing",
    "The Sorry Girls", "Makeup Geek", "Wayne Goss", "FreeCodeCamp.org", "Traversy Media",
    "Justin Guitar", "Drumeo", "Chess.com", "Peter McKinnon", "PHLEARN",
    "Sewing Parts Online", "Crazy Russian Hacker", "Primitive Technology", "Grant Thompson", "The Art Sherpa",
    "Blender Guru", "Langfocus", "Easy Languages", "Khan Academy", "CG Cookie",
    "JunsKitchen", "Maangchi", "ChefSteps", "Joshua Weissman", "Food Wishes",
    "Gentle Whispering ASMR", "The Coding Train", "Corey Schafer", "Academy of Ideas", "School of Life"
]"""

"""search_terms = [
    "Casey Neistat", "Zoella", "Logan Paul", "Shaytards", "Jenna Marbles",
    "David Dobrik", "PewDiePie", "Roman Atwood Vlogs", "Tyler Oakley", "Connor Franta",
    "FunForLouis", "Tanya Burr", "PointlessBlogVlogs", "Safiya Nygaard", "Dude Perfect",
    "Liza Koshy", "The Dolan Twins", "Emma Chamberlain", "James Charles", "Jeffree Star",
    "NikkieTutorials", "Shane Dawson", "Trisha Paytas", "Gigi Gorgeous", "Joey Graceffa",
    "The Ace Family", "The Michalaks", "Sailing La Vagabonde", "Jon Olsson", "Erik Conover",
    "Louis Cole", "Wil Dasovich", "Raya Was Here", "Lost LeBlanc", "Kara and Nate",
    "Sam Kolder", "Peter McKinnon", "Exploring Alternatives", "Vanessa Lau", "GaryVee",
    "Ben Brown", "Lavendaire", "Mimi Ikonn", "Alex Ikonn", "Rachel Aust",
    "The Bucket List Family", "Flying The Nest", "Kombi Life", "Eileen Aldis", "Bald and Bankrupt"
]"""


"""
search_terms = [
    "Intelligence Squared Debates", "Oxford Union", "Cambridge Union", "TED Conferences", "The Doha Debates",
    "Big Think", "The Aspen Institute", "World Economic Forum", "National Geographic", "PBS NewsHour",
    "Democracy Now!", "The Rubin Report", "C-SPAN", "Hoover Institution", "Council on Foreign Relations",
    "Carnegie Council for Ethics in International Affairs", "The Heritage Foundation", "Brookings Institution", "Chatham House", "American Enterprise Institute",
    "Pew Research Center", "The Economist", "Financial Times", "Vox Media", "Vice News",
    "Real Time with Bill Maher", "The Agenda with Steve Paikin", "The Royal Society", "London School of Economics and Political Science", "Harvard University",
    "Stanford University", "Yale University", "Princeton University", "MIT Media Lab", "University of California Television",
    "The New School", "New York Public Library", "Chicago Ideas", "TEDx Talks", "92nd Street Y",
    "Sydney Opera House Talks & Ideas", "RSA Events", "Skepticon", "How To Academy", "Battle of Ideas"
]
"""


def perform_search(search_term):
    deep_search(search_term, existing_videos, depth=5)

    
with ThreadPoolExecutor(max_workers = 32) as executor:
    executor.map(perform_search, search_terms)

end_time = time.time()
ending_videos = str(len(existing_videos))

print("Started with " + start_time + " videos")
print("Started at", start_time)
print("Ending with " + ending_videos + " videos")
print("Ending at", end_time)
# Out:
# Starting with 42304 videos
# Starting at 1708391673.844219
# Search Intelligence Squared Debates Performing search at depth 5
# Search Oxford Union Performing search at depth 5
# Search Cambridge Union Performing search at depth 5
# Search TED Conferences Performing search at depth 5
# Search The Doha Debates Performing search at depth 5
# Search Big Think Performing search at depth 5
# Search The Aspen Institute Performing search at depth 5
# Search World Economic Forum Performing search at depth 5
# Search National Geographic Performing search at depth 5
# Search PBS NewsHour Performing search at depth 5
# Search Democracy Now! Performing search at depth 5
# Search The Rubin Report Performing search at depth 5
# Search C-SPAN Performing search at depth 5
# Search Hoover Institution Performing search at depth 5
# Search Council on Foreign Relations Performing search at depth 5
# Search Carnegie Council for Ethics in International Affairs Performing search at depth 5
# Search The Heritage Foundation Performing search at depth 5
# Search Brookings Institution Performing search at depth 5
# Search Chatham House Performing search at depth 5
# Search American Enterprise Institute Performing search at depth 5
# Search Pew Research Center Performing search at depth 5
# Search The Economist Performing search at depth 5
# Search Financial Times Performing search at depth 5
# Search Vox Media Performing search at depth 5
# Search Vice News Performing search at depth 5
# Search Real Time with Bill Maher Performing search at depth 5
# SearchSearch The Royal Society Performing search at depth 5
#  The Agenda with Steve Paikin Performing search at depth 5
# Search London School of Economics and Political Science Performing search at depth 5
# Search Harvard University Performing search at depth 5
# Search Stanford University Performing search at depth 5
# Search Yale University Performing search at depth 5
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Oxford Union
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Oxford Union
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: The Rubin Report
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Search term: Cambridge Union
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: World Economic Forum
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: The Doha Debates
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Cambridge Union
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Intelligence Squared Debates
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: TED Conferences
# Search term: The Doha Debates
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Big Think
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Intelligence Squared Debates
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: National Geographic
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: TED Conferences
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Search term: Big Think
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Intelligence Squared Debates
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: National Geographic
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: C-SPAN
# Search term: TED Conferences
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: National Geographic
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Hoover Institution
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Pew Research Center
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: The Heritage Foundation
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Brookings Institution
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: PBS NewsHour
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Renderer name: dict_keys(['infoPanelContainerRenderer'])
# Search term: Democracy Now!
# Search term: Vox Media
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Council on Foreign Relations
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: PBS NewsHour
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['adSlotRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Search term: American Enterprise Institute
# Search term: The Agenda with Steve Paikin
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Democracy Now!
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Search term: Council on Foreign Relations
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Search term: The Royal Society
# Search term: Financial Times
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Vice News
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Real Time with Bill Maher
# Renderer name: dict_keys(['adSlotRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Carnegie Council for Ethics in International Affairs
# Search term: Oxford Union
# Unexpected renderer encountered.
# Search term: The Economist
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: American Enterprise Institute
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Democracy Now!
# Renderer name: dict_keys(['adSlotRenderer'])
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Search term: Council on Foreign Relations
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Yale University
# Renderer name: dict_keys(['adSlotRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['adSlotRenderer'])
# Search term: Real Time with Bill Maher
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Harvard University
# Search term: Carnegie Council for Ethics in International Affairs
# Search term: Oxford Union
# Search term: Stanford University
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: American Enterprise Institute
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['adSlotRenderer'])
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Search term: Yale University
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['adSlotRenderer'])
# Renderer name: dict_keys(['adSlotRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Harvard University
# Search term: Carnegie Council for Ethics in International Affairs
# Search term: Stanford University
# Search term: London School of Economics and Political Science
# Search term: American Enterprise Institute
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['adSlotRenderer'])
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Search term: Yale University
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Harvard University
# Search term: Stanford University
# Unexpected renderer encountered.
# Search term: London School of Economics and Political Science
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 167
#     163     deep_search(search_term, existing_videos, depth=5)
#     166 with ThreadPoolExecutor(max_workers = 32) as executor:
# --> 167     executor.map(perform_search, search_terms)
#     169 end_time = time.time()
#     170 ending_videos = str(len(existing_videos))
#
# File /usr/lib64/python3.9/concurrent/futures/_base.py:637, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     636 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 637     self.shutdown(wait=True)
#     638     return False
#
# File /usr/lib64/python3.9/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File /usr/lib64/python3.9/threading.py:1060, in Thread.join(self, timeout)
#    1057     raise RuntimeError("cannot join current thread")
#    1059 if timeout is None:
# -> 1060     self._wait_for_tstate_lock()
#    1061 else:
#    1062     # the behavior of a negative timeout isn't documented, but
#    1063     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1064     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib64/python3.9/threading.py:1080, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1077     return
#    1079 try:
# -> 1080     if lock.acquire(block, timeout):
#    1081         lock.release()
#    1082         self._stop()
#
# KeyboardInterrupt:
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Search term: The Doha Debates
# Unexpected renderer encountered.
# Search term: Yale University
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['adSlotRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Big Think
# Unexpected renderer encountered.
# Search term: Harvard University
# Search term: Stanford University
# Search term: London School of Economics and Political Science
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Search term: Pew Research Center
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Cambridge Union
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Search term: Yale University
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: National Geographic
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: TED Conferences
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Intelligence Squared Debates
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: London School of Economics and Political Science
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Cambridge Union
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Search term: Yale University
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: National Geographic
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: TED Conferences
# Renderer name: dict_keys(['adSlotRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Intelligence Squared Debates
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: London School of Economics and Political Science
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['adSlotRenderer'])
# Search term: Yale University
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Council on Foreign Relations
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: PBS NewsHour
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: PBS NewsHour
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Democracy Now!
# Unexpected renderer encountered.
# Search term: Carnegie Council for Ethics in International Affairs
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Search term: Real Time with Bill Maher
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Democracy Now!
# Unexpected renderer encountered.
# Search term: Carnegie Council for Ethics in International Affairs
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Real Time with Bill Maher
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Harvard University
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Harvard University
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Stanford University
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Stanford University
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search The Rubin Report Found 97 videos
# KyKkia8Mw_o attempt_download called
# KyKkia8Mw_o Skipping, found existing folder.
# ia50QTinbT8 attempt_download called
# ia50QTinbT8 Skipping, found existing folder.
# ZRYlcrGKE-k attempt_download called
# ZRYlcrGKE-k Skipping, found existing folder.
# Lkvpw86iV7s attempt_download called
# Lkvpw86iV7s Skipping, found existing folder.
# -_40_JrUv_Y attempt_download called
# -_40_JrUv_Y Skipping, found existing folder.
# 0SVt0MDIYTE attempt_download called
# 0SVt0MDIYTE Skipping, found existing folder.
# kd7hAUoO028 attempt_download called
# kd7hAUoO028 Skipping, found existing folder.
# dbePI_2YDBM attempt_download called
# dbePI_2YDBM Skipping, found existing folder.
# sWieMROb0ig attempt_download called
# sWieMROb0ig Skipping, found existing folder.
# 8-5auGkAu7Y attempt_download called
# 8-5auGkAu7Y Skipping, found existing folder.
# NEA4M6VMya4 attempt_download called
# NEA4M6VMya4 Skipping, found existing folder.
# V-VjJohZzTI attempt_download called
# V-VjJohZzTI Skipping, found existing folder.
# cSyOX6IKa5Y attempt_download called
# cSyOX6IKa5Y Skipping, found existing folder.
# 5tURYhWbBDY attempt_download called
# 5tURYhWbBDY Skipping, found existing folder.
# hzZQWv5SzvM attempt_download called
# hzZQWv5SzvM Skipping, found existing folder.
# Hm94_IzTuTQ attempt_download called
# Hm94_IzTuTQ Skipping, found existing folder.
# ROiUxBJ_ZCo attempt_download called
# ROiUxBJ_ZCo Skipping, found existing folder.
# n4G2i2XlDGc attempt_download called
# n4G2i2XlDGc Skipping, found existing folder.
# yCwdF8stDyg attempt_download called
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: London School of Economics and Political Science
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Search term: National Geographic
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Search term: London School of Economics and Political Science
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Search term: Yale University
# Search term: National Geographic
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Intelligence Squared Debates
# Unexpected renderer encountered.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Unexpected renderer encountered.
# Search term: Yale University
# Renderer name: dict_keys(['reelShelfRenderer'])
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search term: Intelligence Squared Debates
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: PBS NewsHour
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: PBS NewsHour
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Democracy Now!
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Democracy Now!
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Real Time with Bill Maher
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Real Time with Bill Maher
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search C-SPAN Found 97 videos
# 6VpJKUscNaM attempt_download called
# 6VpJKUscNaM Skipping, found existing folder.
# gh_C0gEkRXs attempt_download called
# gh_C0gEkRXs Skipping, found existing folder.
# PThfYee8aE4 attempt_download called
# PThfYee8aE4 Skipping, found existing folder.
# YX4wZRlrurQ attempt_download called
# YX4wZRlrurQ Skipping, found existing folder.
# 2OiFR-bHvy4 attempt_download called
# 2OiFR-bHvy4 Skipping, found existing folder.
# reN7UYQDQBo attempt_download called
# reN7UYQDQBo Skipping, found existing folder.
# 4rdRZVzhGSs attempt_download called
# 4rdRZVzhGSs Skipping, found existing folder.
# GkKUDT2VTLQ attempt_download called
# GkKUDT2VTLQ Skipping, found existing folder.
# SIZeFoVH8H0 attempt_download called
# SIZeFoVH8H0 Skipping, found existing folder.
# e1lcK3zgrpE attempt_download called
# e1lcK3zgrpE Skipping, found existing folder.
# 0WnQEWKavZ8 attempt_download called
# 0WnQEWKavZ8 Skipping, found existing folder.
# vsOakz6pyNc attempt_download called
# vsOakz6pyNc Skipping, found existing folder.
# vHCAwxFJiM0 attempt_download called
# vHCAwxFJiM0 Skipping, found existing folder.
# l0egtxGLhfA attempt_download called
# l0egtxGLhfA Skipping, found existing folder.
# KFppEuJRTO4 attempt_download called
# KFppEuJRTO4 Skipping, found existing folder.
# lfTlRiAh1cE attempt_download called
# lfTlRiAh1cE Skipping, found existing folder.
# 4F3-QKPL1lQ attempt_download called
# 4F3-QKPL1lQ Skipping, found existing folder.
# 6juxlECbpko attempt_download called
# 6juxlECbpko Skipping, found existing folder.
# C_r9Ayox57Y attempt_download called
# C_r9Ayox57Y Skipping, found existing folder.
# 8XYQ5iX7Dmc attempt_download called
# 8XYQ5iX7Dmc Skipping, found existing folder.
# RPV-G9RxMPc attempt_download called
# RPV-G9RxMPc Skipping, found existing folder.
# K4P-MBCwt5w attempt_download called
# K4P-MBCwt5w Skipping, found existing folder.
# 5xv7sIzTQ24 attempt_download called
# 5xv7sIzTQ24 Skipping, found existing folder.
# Pu_PidqglHI attempt_download called
# Pu_PidqglHI Skipping, found existing folder.
# 5VtAZBvmzcQ attempt_download called
# 5VtAZBvmzcQ Skipping, found existing folder.
# HkAK9QRe4ds attempt_download called
# HkAK9QRe4ds Skipping, found existing folder.
# Q15xhG6pVUw attempt_download called
# Q15xhG6pVUw Skipping, found existing folder.
# Kg96oheeI3g attempt_download called
# Kg96oheeI3g Skipping, found existing folder.
# hT2pp_KrJGg attempt_download called
# hT2pp_KrJGg Skipping, found existing folder.
# iElukq7Mpdg attempt_download called
# iElukq7Mpdg Skipping, found existing folder.
# VIF06g2jK_Q attempt_download called
# VIF06g2jK_Q Skipping, found existing folder.
# Jn2BxPkQQp4 attempt_download called
# Jn2BxPkQQp4 Skipping, found existing folder.
# FzeHy3SGdpk attempt_download called
# FzeHy3SGdpk Skipping, found existing folder.
# QJdnZ0VeAmw attempt_download called
# QJdnZ0VeAmw Skipping, found existing folder.
# rbrUciWxSxU attempt_download called
# Search World Economic Forum Found 98 videos
# Pfcd0gWNIog attempt_download called
# Pfcd0gWNIog Skipping, found existing folder.
# 1Q-fqkewVAI attempt_download called
# 1Q-fqkewVAI Skipping, found existing folder.
# YrnGCXGEPGo attempt_download called
# Search The Heritage Foundation Found 98 videos
# v5rV5aVRYeg attempt_download called
# v5rV5aVRYeg Skipping, found existing folder.
# ftB2auDeFbs attempt_download called
# ftB2auDeFbs Skipping, found existing folder.
# ytI8WiNU0XQ attempt_download called
# ytI8WiNU0XQ Skipping, found existing folder.
# 3tVXi1fP67Q attempt_download called
# 3tVXi1fP67Q Skipping, found existing folder.
# DccqdCURaf8 attempt_download called
# DccqdCURaf8 Skipping, found existing folder.
# Kpff-Wp_lmc attempt_download called
# Kpff-Wp_lmc Skipping, found existing folder.
# doWvaAvOgWg attempt_download called
# doWvaAvOgWg Skipping, found existing folder.
# gOnI6-Qc8vs attempt_download called
# gOnI6-Qc8vs Skipping, found existing folder.
# ESSnRdeaplE attempt_download called
# ESSnRdeaplE Skipping, found existing folder.
# K4xCmiIN-S8 attempt_download called
# K4xCmiIN-S8 Skipping, found existing folder.
# 1Fa167Qv2jQ attempt_download called
# 1Fa167Qv2jQ Skipping, found existing folder.
# uzjdUUdcvSg attempt_download called
# uzjdUUdcvSg Skipping, found existing folder.
# T9qP6TuX1ls attempt_download called
# T9qP6TuX1ls Skipping, found existing folder.
# QTd5g9NYue8 attempt_download called
# QTd5g9NYue8 Skipping, found existing folder.
# BocbcP-sA0Y attempt_download called
# BocbcP-sA0Y Skipping, found existing folder.
# _9AfhdKLNDA attempt_download called
# _9AfhdKLNDA Skipping, found existing folder.
# bM4hwUyHeaI attempt_download called
# bM4hwUyHeaI Skipping, found existing folder.
# N32UPXGChgo attempt_download called
# N32UPXGChgo Skipping, found existing folder.
# vRQYtdWQoUQ attempt_download called
# vRQYtdWQoUQ Skipping, found existing folder.
# 4eTG32YC_Uw attempt_download called
# 4eTG32YC_Uw Skipping, found existing folder.
# Q7uxqjz_xsg attempt_download called
# Search The Aspen Institute Found 96 videos
# 7brS6N7RDqY attempt_download called
# 7brS6N7RDqY Skipping, found existing folder.
# KzLpryLUYsk attempt_download called
# KzLpryLUYsk Skipping, found existing folder.
# iGW7wTozsHs attempt_download called
# iGW7wTozsHs Skipping, found existing folder.
# ATJiRuAci-M attempt_download called
# ATJiRuAci-M Skipping, found existing folder.
# v6H2HmKDbZA attempt_download called
# v6H2HmKDbZA Skipping, found existing folder.
# rpOsdGSUp2U attempt_download called
# rpOsdGSUp2U Skipping, found existing folder.
# 0Mhes3rYDDc attempt_download called
# 0Mhes3rYDDc Skipping, found existing folder.
# 5yMOE7Y2dAQ attempt_download called
# 5yMOE7Y2dAQ Skipping, found existing folder.
# rPshEdJvKj4 attempt_download called
# rPshEdJvKj4 Skipping, found existing folder.
# Ssa3khCyYAI attempt_download called
# Ssa3khCyYAI Skipping, found existing folder.
# Ab0EUvQB8kY attempt_download called
# Ab0EUvQB8kY Skipping, found existing folder.
# rupCi5CM0So attempt_download called
# rupCi5CM0So Skipping, found existing folder.
# FQPTNSyzLCs attempt_download called
# FQPTNSyzLCs Skipping, found existing folder.
# q6bM28qLpl8 attempt_download called
# q6bM28qLpl8 Skipping, found existing folder.
# SzkBzCjcO8Q attempt_download called
# SzkBzCjcO8Q Skipping, found existing folder.
# b3p-M0H7cqE attempt_download called
# b3p-M0H7cqE Skipping, found existing folder.
# ePJCuuMoBy0 attempt_download called
# ePJCuuMoBy0 Skipping, found existing folder.
# WVVDjYcK-Tw attempt_download called
# WVVDjYcK-Tw Skipping, found existing folder.
# 7VOMFjQfJ8w attempt_download called
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Harvard University
# Search term: Stanford University
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Harvard University
# Search term: Stanford University
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Yale University
# Search Oxford Union Found 97 videos
# gWnMgMEVABM attempt_download called
# gWnMgMEVABM Skipping, found existing folder.
# sP08sIKXdLE attempt_download called
# sP08sIKXdLE Skipping, found existing folder.
# -1NFirxhXWE attempt_download called
# -1NFirxhXWE Skipping, found existing folder.
# F4GGxcHijNk attempt_download called
# F4GGxcHijNk Skipping, found existing folder.
# DmmSDfc2Qo8 attempt_download called
# Search Pew Research Center Found 99 videos
# BmGVQouqz1s attempt_download called
# BmGVQouqz1s Skipping, found existing folder.
# eFzGdQrr2K8 attempt_download called
# eFzGdQrr2K8 Skipping, found existing folder.
# NMUIoxXU8m8 attempt_download called
# NMUIoxXU8m8 Skipping, found existing folder.
# tdxhDHcF5Fc attempt_download called
# tdxhDHcF5Fc Skipping, found existing folder.
# ykr4WeHaJNE attempt_download called
# ykr4WeHaJNE Skipping, found existing folder.
# l2WaNmhvEzo attempt_download called
# l2WaNmhvEzo Skipping, found existing folder.
# hPCoDz_CPCc attempt_download called
# hPCoDz_CPCc Skipping, found existing folder.
# ZJn6vMjHhCA attempt_download called
# ZJn6vMjHhCA Skipping, found existing folder.
# xGKGBT4NAgI attempt_download called
# Search The Doha Debates Found 90 videos
# 4kZsGihcuKY attempt_download called
# 4kZsGihcuKY Skipping, found existing folder.
# 8P9AOrryvqs attempt_download called
# 8P9AOrryvqs Skipping, found existing folder.
# dHh8PK-e70Q attempt_download called
# dHh8PK-e70Q Skipping, found existing folder.
# oWMH6zEUvSI attempt_download called
# oWMH6zEUvSI Skipping, found existing folder.
# vaRfKhjpZOU attempt_download called
# vaRfKhjpZOU Skipping, found existing folder.
# FgFNhR3cDdI attempt_download called
# FgFNhR3cDdI Skipping, found existing folder.
# glYNs5uOuRc attempt_download called
# glYNs5uOuRc Skipping, found existing folder.
# ffG2EdYxoCQ attempt_download called
# ffG2EdYxoCQ Skipping, found existing folder.
# GkitwC9HSOc attempt_download called
# GkitwC9HSOc Skipping, found existing folder.
# h-PFkR0j-yI attempt_download called
# h-PFkR0j-yI Skipping, found existing folder.
# obKbBSCemmo attempt_download called
# obKbBSCemmo Skipping, found existing folder.
# W67MFNMVEgk attempt_download called
# W67MFNMVEgk Skipping, found existing folder.
# Q21Y39C_X80 attempt_download called
# Q21Y39C_X80 Skipping, found existing folder.
# EoMN0TCqsQM attempt_download called
# EoMN0TCqsQM Skipping, found existing folder.
# _UfwmJ4H3T4 attempt_download called
# _UfwmJ4H3T4 Skipping, found existing folder.
# EdYCX0G1jSg attempt_download called
# EdYCX0G1jSg Skipping, found existing folder.
# pPpLWf2df3Y attempt_download called
# Search The Royal Society Found 96 videos
# eSWwIQzKsbY attempt_download called
# eSWwIQzKsbY Skipping, found existing folder.
# GlWNuzrqe7U attempt_download called
# GlWNuzrqe7U Skipping, found existing folder.
# dVp9Z5k0dEE attempt_download called
# dVp9Z5k0dEE Skipping, found existing folder.
# Am2mo7BhQrQ attempt_download called
# Am2mo7BhQrQ Skipping, found existing folder.
# MmJUj4Aa2kM attempt_download called
# MmJUj4Aa2kM Skipping, found existing folder.
# 3duBeFEnyU8 attempt_download called
# 3duBeFEnyU8 Skipping, found existing folder.
# LUqwHnsLIu8 attempt_download called
# LUqwHnsLIu8 Skipping, found existing folder.
# t_NEPRy10vI attempt_download called
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Yale University
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search Chatham House Found 98 videos
# IsgTt5tldww attempt_download called
# IsgTt5tldww Skipping, found existing folder.
# gW6nirXos5A attempt_download called
# gW6nirXos5A Skipping, found existing folder.
# gU11PM_QIzU attempt_download called
# gU11PM_QIzU Skipping, found existing folder.
# nill8M_Qi-Y attempt_download called
# nill8M_Qi-Y Skipping, found existing folder.
# 2wTUPSJDQzo attempt_download called
# 2wTUPSJDQzo Skipping, found existing folder.
# lHuXUeq6XH8 attempt_download called
# lHuXUeq6XH8 Skipping, found existing folder.
# mZDNn17YBQI attempt_download called
# mZDNn17YBQI Skipping, found existing folder.
# HNhL2Yf7Ao4 attempt_download called
# HNhL2Yf7Ao4 Skipping, found existing folder.
# GK7OeRUzKIw attempt_download called
# GK7OeRUzKIw Skipping, found existing folder.
# WWb2js6FgEc attempt_download called
# WWb2js6FgEc Skipping, found existing folder.
# 2nT4lngp600 attempt_download called
# 2nT4lngp600 Skipping, found existing folder.
# halMzmvRfC0 attempt_download called
# Search Brookings Institution Found 98 videos
# UWD0qMFkVYw attempt_download called
# UWD0qMFkVYw Skipping, found existing folder.
# DkpgGM5Lkls attempt_download called
# DkpgGM5Lkls Skipping, found existing folder.
# hTJg4uqib1o attempt_download called
# hTJg4uqib1o Skipping, found existing folder.
# DvoblmoQbzE attempt_download called
# DvoblmoQbzE Skipping, found existing folder.
# mbfdaMYveho attempt_download called
# mbfdaMYveho Skipping, found existing folder.
# 2OmfIeGtL1w attempt_download called
# 2OmfIeGtL1w Skipping, found existing folder.
# BqheqCDg0q0 attempt_download called
# BqheqCDg0q0 Skipping, found existing folder.
# oeW787KQODI attempt_download called
# oeW787KQODI Skipping, found existing folder.
# qbeuG-lGiyU attempt_download called
# qbeuG-lGiyU Skipping, found existing folder.
# cFll4OUVUSg attempt_download called
# cFll4OUVUSg Skipping, found existing folder.
# ltqprmE_Co8 attempt_download called
# ltqprmE_Co8 Skipping, found existing folder.
# URRhjgoKRkA attempt_download called
# URRhjgoKRkA Skipping, found existing folder.
# ZJgk8-GF3uI attempt_download called
# ZJgk8-GF3uI Skipping, found existing folder.
# k0YmRe3b3d8 attempt_download called
# k0YmRe3b3d8 Skipping, found existing folder.
# 4P0ojW9L4ic attempt_download called
# 4P0ojW9L4ic Skipping, found existing folder.
# vUfwgi8hw6s attempt_download called
# vUfwgi8hw6s Skipping, found existing folder.
# -bs5QYr-wO8 attempt_download called
# -bs5QYr-wO8 Skipping, found existing folder.
# GW3JIH3rK_U attempt_download called
# GW3JIH3rK_U Skipping, found existing folder.
# 2dJw6ZFqo6o attempt_download called
# 2dJw6ZFqo6o Skipping, found existing folder.
# qfZ0Z84wmrY attempt_download called
# qfZ0Z84wmrY Skipping, found existing folder.
# ayMivdZWTDc attempt_download called
# ayMivdZWTDc Skipping, found existing folder.
# t6gJcIl1Xy8 attempt_download called
# t6gJcIl1Xy8 Skipping, found existing folder.
# z0j1gRSYghs attempt_download called
# z0j1gRSYghs Skipping, found existing folder.
# Xadq9AYqnEg attempt_download called
# Xadq9AYqnEg Skipping, found existing folder.
# jQHET-uR8AY attempt_download called
# jQHET-uR8AY Skipping, found existing folder.
# UkR_Osu1dMA attempt_download called
# UkR_Osu1dMA Skipping, found existing folder.
# bSJxHhzU0fo attempt_download called
# bSJxHhzU0fo Skipping, found existing folder.
# AZ-VTduhVCs attempt_download called
# AZ-VTduhVCs Skipping, found existing folder.
# xEDDrHnp_eU attempt_download called
# xEDDrHnp_eU Skipping, found existing folder.
# iu3uaY3VDOc attempt_download called
# iu3uaY3VDOc Skipping, found existing folder.
# Ed6aSV9LKlw attempt_download called
# Ed6aSV9LKlw Skipping, found existing folder.
# CzjRhcCuc0I attempt_download called
# Search Financial Times Found 95 videos
# 87YaO-F-xxA attempt_download called
# 87YaO-F-xxA Skipping, found existing folder.
# cfaubxeS5HU attempt_download called
# cfaubxeS5HU Skipping, found existing folder.
# VG50d67E838 attempt_download called
# VG50d67E838 Skipping, found existing folder.
# j-cLiO0AFDc attempt_download called
# j-cLiO0AFDc Skipping, found existing folder.
# 3njfN0IOz38 attempt_download called
# 3njfN0IOz38 Skipping, found existing folder.
# XSbNUwWkHmM attempt_download called
# XSbNUwWkHmM Skipping, found existing folder.
# P2UpenE_oWM attempt_download called
# P2UpenE_oWM Skipping, found existing folder.
# IR0BXeNdhQs attempt_download called
# IR0BXeNdhQs Skipping, found existing folder.
# FhMHypTf5vM attempt_download called
# FhMHypTf5vM Skipping, found existing folder.
# i8iHzXHt9iw attempt_download called
# i8iHzXHt9iw Skipping, found existing folder.
# YZsJNOdJRNo attempt_download called
# YZsJNOdJRNo Skipping, found existing folder.
# _TOCRjF9WuE attempt_download called
# _TOCRjF9WuE Skipping, found existing folder.
# NYAiuqU20iQ attempt_download called
# NYAiuqU20iQ Skipping, found existing folder.
# S-KBsPOZJF8 attempt_download called
# S-KBsPOZJF8 Skipping, found existing folder.
# JBRzr0nT_98 attempt_download called
# JBRzr0nT_98 Skipping, found existing folder.
# WCmO0fre9Fc attempt_download called
# WCmO0fre9Fc Skipping, found existing folder.
# lFAQ0Euv724 attempt_download called
# lFAQ0Euv724 Skipping, found existing folder.
# pFkxJSCzjcw attempt_download called
# pFkxJSCzjcw Skipping, found existing folder.
# -eh4RK8bkZE attempt_download called
# Unexpected renderer encountered.
# Search Vox Media Found 96 videos
# sJs_64OUpEs attempt_download called
# sJs_64OUpEs Skipping, found existing folder.
# yvdtWfHpCR4 attempt_download called
# yvdtWfHpCR4 Skipping, found existing folder.
# f5acbuOuCR0 attempt_download called
# f5acbuOuCR0 Skipping, found existing folder.
# JjAwOSNEupM attempt_download called
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Intelligence Squared Debates
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Intelligence Squared Debates
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search TED Conferences Found 88 videos
# 8jPQjjsBbIc attempt_download called
# 8jPQjjsBbIc Skipping, found existing folder.
# v9f6twy70iM attempt_download called
# v9f6twy70iM Skipping, found existing folder.
# l4Lq7gaKW4A attempt_download called
# Search Hoover Institution Found 98 videos
# DAUJSAcCldc attempt_download called
# DAUJSAcCldc Skipping, found existing folder.
# LpMQSVp7NTg attempt_download called
# LpMQSVp7NTg Skipping, found existing folder.
# pn2gda_phAA attempt_download called
# pn2gda_phAA Skipping, found existing folder.
# 0XqZ6L0MgQo attempt_download called
# 0XqZ6L0MgQo Skipping, found existing folder.
# QPc46gpHYw4 attempt_download called
# QPc46gpHYw4 Skipping, found existing folder.
# IL4Jxa6v4JA attempt_download called
# IL4Jxa6v4JA Skipping, found existing folder.
# LMRYvl2Jefg attempt_download called
# LMRYvl2Jefg Skipping, found existing folder.
# wJY-1alhpJM attempt_download called
# wJY-1alhpJM Skipping, found existing folder.
# AQTmVrlolSY attempt_download called
# AQTmVrlolSY Skipping, found existing folder.
# NAZw_Elft_Y attempt_download called
# NAZw_Elft_Y Skipping, found existing folder.
# d90QqLOghGU attempt_download called
# d90QqLOghGU Skipping, found existing folder.
# AlL9uHaeNqo attempt_download called
# AlL9uHaeNqo Skipping, found existing folder.
# wS9FsR9PMSk attempt_download called
# wS9FsR9PMSk Skipping, found existing folder.
# 7OKo0l7xzVs attempt_download called
# 7OKo0l7xzVs Skipping, found existing folder.
# O5Bc2pFVVN0 attempt_download called
# O5Bc2pFVVN0 Skipping, found existing folder.
# C10y3kbYlmk attempt_download called
# C10y3kbYlmk Skipping, found existing folder.
# KE7QOrtSDxE attempt_download called
# KE7QOrtSDxE Skipping, found existing folder.
# 9SrOTSi3BEw attempt_download called
# 9SrOTSi3BEw Skipping, found existing folder.
# TzzpJtO08P4 attempt_download called
# TzzpJtO08P4 Skipping, found existing folder.
# iz7Aa2NMCXQ attempt_download called
# iz7Aa2NMCXQ Skipping, found existing folder.
# JXxFoK_40Dc attempt_download called
# JXxFoK_40Dc Skipping, found existing folder.
# K_Boypy3E2c attempt_download called
# K_Boypy3E2c Skipping, found existing folder.
# MphcX-WQHOs attempt_download called
# MphcX-WQHOs Skipping, found existing folder.
# xzsluXI1R8o attempt_download called
# xzsluXI1R8o Skipping, found existing folder.
# fhMX2AB8mjA attempt_download called
# fhMX2AB8mjA Skipping, found existing folder.
# U-1HLIYhNYo attempt_download called
# U-1HLIYhNYo Skipping, found existing folder.
# ycWnVr5hA-I attempt_download called
# ycWnVr5hA-I Skipping, found existing folder.
# 9mkF2tIm6wQ attempt_download called
# 9mkF2tIm6wQ Skipping, found existing folder.
# rXexaVsvhCM attempt_download called
# rXexaVsvhCM Skipping, found existing folder.
# gVTdctBh4_Y attempt_download called
# gVTdctBh4_Y Skipping, found existing folder.
# XtfNKR3LufI attempt_download called
# XtfNKR3LufI Skipping, found existing folder.
# -806XKuBUnY attempt_download called
# -806XKuBUnY Skipping, found existing folder.
# 8NhiY0ZamR0 attempt_download called
# 8NhiY0ZamR0 Skipping, found existing folder.
# 5FZxdS5LD1A attempt_download called
# 5FZxdS5LD1A Skipping, found existing folder.
# 3ww4ofe0v70 attempt_download called
# 3ww4ofe0v70 Skipping, found existing folder.
# qg3GTVlwjoE attempt_download called
# qg3GTVlwjoE Skipping, found existing folder.
# KDLTUMIR4jg attempt_download called
# KDLTUMIR4jg Skipping, found existing folder.
# o2u54a1FL28 attempt_download called
# o2u54a1FL28 Skipping, found existing folder.
# 6ZcWa5-DFW4 attempt_download called
# 6ZcWa5-DFW4 Skipping, found existing folder.
# oAtj5oxRC-0 attempt_download called
# oAtj5oxRC-0 Skipping, found existing folder.
# 1fgDu57N-Qw attempt_download called
# 1fgDu57N-Qw Skipping, found existing folder.
# 0w5FNux8ez8 attempt_download called
# 0w5FNux8ez8 Skipping, found existing folder.
# lD3RHUmol5Q attempt_download called
# lD3RHUmol5Q Skipping, found existing folder.
# kfFRjfItzVA attempt_download called
# kfFRjfItzVA Skipping, found existing folder.
# bGv2yngbpus attempt_download called
# bGv2yngbpus Skipping, found existing folder.
# GKZZF_nARW8 attempt_download called
# GKZZF_nARW8 Skipping, found existing folder.
# 0yxwau6GAhU attempt_download called
# 0yxwau6GAhU Skipping, found existing folder.
# 3t6a7Gj0ubc attempt_download called
# 3t6a7Gj0ubc Skipping, found existing folder.
# mS5WYp5xmvI attempt_download called
# mS5WYp5xmvI Skipping, found existing folder.
# IZwSxMeY4eA attempt_download called
# IZwSxMeY4eA Skipping, found existing folder.
# R7RMfByqv7g attempt_download called
# R7RMfByqv7g Skipping, found existing folder.
# lp4XhZytdD0 attempt_download called
# lp4XhZytdD0 Skipping, found existing folder.
# KHRx5CNbQtU attempt_download called
# KHRx5CNbQtU Skipping, found existing folder.
# ul1gsIdlJFs attempt_download called
# ul1gsIdlJFs Skipping, found existing folder.
# noj4phMT9OE attempt_download called
# noj4phMT9OE Skipping, found existing folder.
# FlJTl2LS9j0 attempt_download called
# FlJTl2LS9j0 Skipping, found existing folder.
# jhi2icRXbHo attempt_download called
# jhi2icRXbHo Skipping, found existing folder.
# 4sM5sQIZXlg attempt_download called
# 4sM5sQIZXlg Skipping, found existing folder.
# ZV8EouNdGIc attempt_download called
# ZV8EouNdGIc Skipping, found existing folder.
# uNdnlrkx-wg attempt_download called
# uNdnlrkx-wg Skipping, found existing folder.
# yr4Sdnk4NlU attempt_download called
# yr4Sdnk4NlU Skipping, found existing folder.
# c0Zv7MGPpIo attempt_download called
# c0Zv7MGPpIo Skipping, found existing folder.
# 0iRvEPcQV3I attempt_download called
# 0iRvEPcQV3I Skipping, found existing folder.
# Bx2hEc7Dlcg attempt_download called
# Bx2hEc7Dlcg Skipping, found existing folder.
# go8uMp-gUsY attempt_download called
# go8uMp-gUsY Skipping, found existing folder.
# jaPF50Y2fgk attempt_download called
# jaPF50Y2fgk Skipping, found existing folder.
# M5z5HUS4tmM attempt_download called
# M5z5HUS4tmM Skipping, found existing folder.
# SVk7yjD2nWk attempt_download called
# SVk7yjD2nWk Skipping, found existing folder.
# eTVExp4pj_I attempt_download called
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: PBS NewsHour
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: PBS NewsHour
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Real Time with Bill Maher
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Real Time with Bill Maher
# Search The Agenda with Steve Paikin Found 99 videos
# rFVHUOT4Vyk attempt_download called
# rFVHUOT4Vyk Skipping, found existing folder.
# H7GSRt8dYe8 attempt_download called
# H7GSRt8dYe8 Skipping, found existing folder.
# zf276pdUC8Y attempt_download called
# zf276pdUC8Y Skipping, found existing folder.
# 5XyU--hEKAk attempt_download called
# 5XyU--hEKAk Skipping, found existing folder.
# P9k0bA5CQGE attempt_download called
# P9k0bA5CQGE Skipping, found existing folder.
# RLPKMK8Q-sA attempt_download called
# RLPKMK8Q-sA Skipping, found existing folder.
# GiGTWhSFz2k attempt_download called
# GiGTWhSFz2k Skipping, found existing folder.
# gomI_Yh-0c4 attempt_download called
# gomI_Yh-0c4 Skipping, found existing folder.
# _H0uUj5peTM attempt_download called
# _H0uUj5peTM Skipping, found existing folder.
# kbfla1q60TA attempt_download called
# kbfla1q60TA Skipping, found existing folder.
# W_-uhO1KTGc attempt_download called
# W_-uhO1KTGc Skipping, found existing folder.
# 3Ybg16RNc5g attempt_download called
# 3Ybg16RNc5g Skipping, found existing folder.
# 4Qo6kYCvb1c attempt_download called
# 4Qo6kYCvb1c Skipping, found existing folder.
# yHhjP8s05Sk attempt_download called
# yHhjP8s05Sk Skipping, found existing folder.
# ivRFqa9GLLs attempt_download called
# ivRFqa9GLLs Skipping, found existing folder.
# YmZ8LkjDWuA attempt_download called
# YmZ8LkjDWuA Skipping, found existing folder.
# tMzBnrOIkwY attempt_download called
# tMzBnrOIkwY Skipping, found existing folder.
# uMRPgPrRNUU attempt_download called
# uMRPgPrRNUU Skipping, found existing folder.
# N6omsBrFT4Q attempt_download called
# N6omsBrFT4Q Skipping, found existing folder.
# uiZY5o-R3lA attempt_download called
# uiZY5o-R3lA Skipping, found existing folder.
# _hiERLqHU-k attempt_download called
# _hiERLqHU-k Skipping, found existing folder.
# HzzA_38sKvA attempt_download called
# HzzA_38sKvA Skipping, found existing folder.
# x9waKuCANQQ attempt_download called
# x9waKuCANQQ Skipping, found existing folder.
# IkCbJHPMNyY attempt_download called
# IkCbJHPMNyY Skipping, found existing folder.
# khfVLmLUipQ attempt_download called
# khfVLmLUipQ Skipping, found existing folder.
# h0eYV_at2MU attempt_download called
# h0eYV_at2MU Skipping, found existing folder.
# J0HU7qjy52Q attempt_download called
# J0HU7qjy52Q Skipping, found existing folder.
# 0DpfsbhOqYY attempt_download called
# 0DpfsbhOqYY Skipping, found existing folder.
# KNXZ87mTov8 attempt_download called
# KNXZ87mTov8 Skipping, found existing folder.
# o7ll-HSnvgc attempt_download called
# o7ll-HSnvgc Skipping, found existing folder.
# oSXWdphzTEM attempt_download called
# oSXWdphzTEM Skipping, found existing folder.
# BqkCxWmSQL4 attempt_download called
# BqkCxWmSQL4 Skipping, found existing folder.
# ZhJd_kIE6aw attempt_download called
# ZhJd_kIE6aw Skipping, found existing folder.
# bYWmufAUZYA attempt_download called
# bYWmufAUZYA Skipping, found existing folder.
# bYMBuOLkaj0 attempt_download called
# bYMBuOLkaj0 Skipping, found existing folder.
# tRZPR0GwUbE attempt_download called
# tRZPR0GwUbE Skipping, found existing folder.
# tvO2GS3rVcE attempt_download called
# tvO2GS3rVcE Skipping, found existing folder.
# XMxWxtgXWXA attempt_download called
# XMxWxtgXWXA Skipping, found existing folder.
# FjmQ7-_4UuM attempt_download called
# FjmQ7-_4UuM Skipping, found existing folder.
# jUVNeHC6Cs4 attempt_download called
# jUVNeHC6Cs4 Skipping, found existing folder.
# LGf1wlKllVg attempt_download called
# LGf1wlKllVg Skipping, found existing folder.
# fxsqT6dwAio attempt_download called
# fxsqT6dwAio Skipping, found existing folder.
# uPD-akQhRvg attempt_download called
# uPD-akQhRvg Skipping, found existing folder.
# 0LAqEqZS898 attempt_download called
# 0LAqEqZS898 Skipping, found existing folder.
# YbmW0f8caAo attempt_download called
# YbmW0f8caAo Skipping, found existing folder.
# 5AmveDRIxgg attempt_download called
# 5AmveDRIxgg Skipping, found existing folder.
# _z768MZ2KtY attempt_download called
# _z768MZ2KtY Skipping, found existing folder.
# ze3xKIAAztQ attempt_download called
# ze3xKIAAztQ Skipping, found existing folder.
# O0PHtnTw5uQ attempt_download called
# O0PHtnTw5uQ Skipping, found existing folder.
# xlkZnwFOwKE attempt_download called
# xlkZnwFOwKE Skipping, found existing folder.
# DBfbfMSrjoY attempt_download called
# DBfbfMSrjoY Skipping, found existing folder.
# AVIqFVT3KEc attempt_download called
# AVIqFVT3KEc Skipping, found existing folder.
# _O0nMiUVZmc attempt_download called
# _O0nMiUVZmc Skipping, found existing folder.
# xBYiR0mrR78 attempt_download called
# xBYiR0mrR78 Skipping, found existing folder.
# j3nTer-OXWA attempt_download called
# j3nTer-OXWA Skipping, found existing folder.
# IGBKMRcl_Kw attempt_download called
# IGBKMRcl_Kw Skipping, found existing folder.
# 9T1VckoMNNY attempt_download called
# 9T1VckoMNNY Skipping, found existing folder.
# 18K3cQP3mTc attempt_download called
# 18K3cQP3mTc Skipping, found existing folder.
# Ck2K4DSn2Xk attempt_download called
# Ck2K4DSn2Xk Skipping, found existing folder.
# -Bg7DC7n-eU attempt_download called
# -Bg7DC7n-eU Skipping, found existing folder.
# YOzOo1CRH0k attempt_download called
# YOzOo1CRH0k Skipping, found existing folder.
# KAec2vlUZbw attempt_download called
# KAec2vlUZbw Skipping, found existing folder.
# XJl3WSnLPqU attempt_download called
# XJl3WSnLPqU Skipping, found existing folder.
# 3CrSk3ZqiXQ attempt_download called
# 3CrSk3ZqiXQ Skipping, found existing folder.
# qXfMrj5lRQs attempt_download called
# qXfMrj5lRQs Skipping, found existing folder.
# 75dqyNArmOw attempt_download called
# 75dqyNArmOw Skipping, found existing folder.
# vcId_HIVhH0 attempt_download called
# vcId_HIVhH0 Skipping, found existing folder.
# 9SkJGIxe3yM attempt_download called
# 9SkJGIxe3yM Skipping, found existing folder.
# Q_R2CdxOnm8 attempt_download called
# Q_R2CdxOnm8 Skipping, found existing folder.
# CCpX3t-ko6I attempt_download called
# CCpX3t-ko6I Skipping, found existing folder.
# oSXpg-Izcik attempt_download called
# oSXpg-Izcik Skipping, found existing folder.
# PpmcIyfi36A attempt_download called
# PpmcIyfi36A Skipping, found existing folder.
# fJqU2A5terk attempt_download called
# fJqU2A5terk Skipping, found existing folder.
# ohHcT0UATSI attempt_download called
# ohHcT0UATSI Skipping, found existing folder.
# 1JeQ5EDL0jw attempt_download called
# 1JeQ5EDL0jw Skipping, found existing folder.
# HMHudcRDaio attempt_download called
# HMHudcRDaio Skipping, found existing folder.
# mMTCk0bPY_E attempt_download called
# mMTCk0bPY_E Skipping, found existing folder.
# H9qnkXdDfL8 attempt_download called
# H9qnkXdDfL8 Skipping, found existing folder.
# kasiov0ytEc attempt_download called
# kasiov0ytEc Skipping, found existing folder.
# Yz42Zv54Sv4 attempt_download called
# Yz42Zv54Sv4 Skipping, found existing folder.
# 4fLUmzhqkAw attempt_download called
# 4fLUmzhqkAw Skipping, found existing folder.
# QHal0SwTAuA attempt_download called
# QHal0SwTAuA Skipping, found existing folder.
# XzYRghZ3eKQ attempt_download called
# XzYRghZ3eKQ Skipping, found existing folder.
# Qs7p0IXZ0wk attempt_download called
# Qs7p0IXZ0wk Skipping, found existing folder.
# B0ikc7C31kY attempt_download called
# B0ikc7C31kY Skipping, found existing folder.
# Bv2cAEHeyPM attempt_download called
# Bv2cAEHeyPM Skipping, found existing folder.
# GtPapsuTEiA attempt_download called
# GtPapsuTEiA Skipping, found existing folder.
# VeOxFCl2AOM attempt_download called
# VeOxFCl2AOM Skipping, found existing folder.
# Q_bQzxmbP78 attempt_download called
# Q_bQzxmbP78 Skipping, found existing folder.
# WvWZagoudx0 attempt_download called
# WvWZagoudx0 Skipping, found existing folder.
# hvFOSkO1h9I attempt_download called
# hvFOSkO1h9I Skipping, found existing folder.
# 4e492Qb5fNo attempt_download called
# 4e492Qb5fNo Skipping, found existing folder.
# fk1Q1gonYc0 attempt_download called
# fk1Q1gonYc0 Skipping, found existing folder.
# QHIFo-UiLnc attempt_download called
# QHIFo-UiLnc Skipping, found existing folder.
# PRMlR6rDigM attempt_download called
# PRMlR6rDigM Skipping, found existing folder.
# rDQ9oQUUS-8 attempt_download called
# rDQ9oQUUS-8 Skipping, found existing folder.
# AxJr01kI_68 attempt_download called
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search Big Think Found 97 videos
# Azky23nqQds attempt_download called
# Azky23nqQds Skipping, found existing folder.
# 7yLeDg_KuOA attempt_download called
# 7yLeDg_KuOA Skipping, found existing folder.
# 4mPZC8QQXCo attempt_download called
# 4mPZC8QQXCo Skipping, found existing folder.
# LTaPtQMHBxQ attempt_download called
# LTaPtQMHBxQ Skipping, found existing folder.
# HPsz4ipF4i4 attempt_download called
# HPsz4ipF4i4 Skipping, found existing folder.
# e-or_D-qNqM attempt_download called
# e-or_D-qNqM Skipping, found existing folder.
# H5Q_-gIZIps attempt_download called
# H5Q_-gIZIps Skipping, found existing folder.
# tpPFdFdfxxM attempt_download called
# tpPFdFdfxxM Skipping, found existing folder.
# BjmPvovl-V4 attempt_download called
# BjmPvovl-V4 Skipping, found existing folder.
# Ywec1MbeQDk attempt_download called
# Ywec1MbeQDk Skipping, found existing folder.
# PuAwied4x2Q attempt_download called
# PuAwied4x2Q Skipping, found existing folder.
# GF-xvBXgqa4 attempt_download called
# GF-xvBXgqa4 Skipping, found existing folder.
# zBN5aa3jAHw attempt_download called
# zBN5aa3jAHw Skipping, found existing folder.
# vqJQvJ7i7Ek attempt_download called
# vqJQvJ7i7Ek Skipping, found existing folder.
# znwUCNrjpD4 attempt_download called
# znwUCNrjpD4 Skipping, found existing folder.
# 5EwVBC3VsRA attempt_download called
# 5EwVBC3VsRA Skipping, found existing folder.
# ugIuHWc6Nuc attempt_download called
# ugIuHWc6Nuc Skipping, found existing folder.
# 5ORz1-LWrjo attempt_download called
# 5ORz1-LWrjo Skipping, found existing folder.
# xFRZuh0f9Ys attempt_download called
# Search Vice News Found 97 videos
# dRiAnrfX3Io attempt_download called
# dRiAnrfX3Io Skipping, found existing folder.
# 0cjli_oQC-s attempt_download called
# Search Cambridge Union Found 98 videos
# FtX1-OBeEQU attempt_download called
# Search National Geographic Found 93 videos
# gdYOTfyTgR8 attempt_download called
# gdYOTfyTgR8 Skipping, found existing folder.
# BJ3Yv572V1A attempt_download called
# BJ3Yv572V1A Skipping, found existing folder.
# m1IUGdK7X0U attempt_download called
# m1IUGdK7X0U Skipping, found existing folder.
# CCM7cbDIcug attempt_download called
# CCM7cbDIcug Skipping, found existing folder.
# MzB1WOJUenY attempt_download called
# MzB1WOJUenY Skipping, found existing folder.
# lUsBDbq9l0E attempt_download called
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Council on Foreign Relations
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.

# %%
import glob
import os
from moviepy.editor import AudioFileClip

def static_analysis(location):
    folders = {x for x in os.listdir(location)}
    print("Videos crawled:", len(folders))
    print()
    
    has_audio = 0 
    has_at_least_one_transcript = 0
    
    total_bytes = 0
    total_length = 0
    transcripts = {}   

    for folder in folders[:500]:
        if not os.path.exists(location + folder + "/audio.mp4"):
            continue
        total_bytes += os.path.getsize(location + folder + "/audio.mp4")
        if total_bytes == 0:
            continue
        has_audio += 1
        with AudioFileClip(location + folder + "/audio.mp4") as audio:
            total_length += audio.duration
        has_transcript = False
        for file in os.listdir(location + folder):
            if ".json" in file:
                has_transcript = True
                language = file.replace("caption-", "").replace(".json", "")
                if language not in transcripts:
                    transcripts[language] = 0
                transcripts[language] += 1
        if has_transcript:
            has_at_least_one_transcript += 1
        
    print("Downloaded mp4 Files:", has_audio)
    print("Total mp4 Audio Duration (seconds):", int(total_length))
    print("Total mp4 Filesize (bytes):", total_bytes)
    print()
    
    transcripts = sorted(transcripts.items(), key=lambda item: item[1], reverse=True)
    print("Has at least one transcript:", has_at_least_one_transcript)
    for language, count in transcripts:
        print("Transcripts of language", language + ":", count)

static_analysis("dataset-4/")
# Out:
# Videos crawled: 5367
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 47
#      44     for language, count in transcripts:
#      45         print("Transcripts of language", language + ":", count)
# ---> 47 static_analysis("dataset-3/")
#
# Cell In[10], line 17, in static_analysis(location)
#      14 total_length = 0
#      15 transcripts = {}
# ---> 17 for folder in folders[:500]:
#      18     if not os.path.exists(location + folder + "/audio.mp4"):
#      19         continue
#
# TypeError: 'set' object is not subscriptable
