# %%
import os
import json

def attempt_download(yt_obj, existing_videos, location = "dataset/"):
    vid = yt_obj.video_id
    print(vid, "attempt_download called")
    if vid in existing_videos:
        print(vid, "Skipping, found existing folder.")
        return False
    
    os.makedirs(location + vid)
    try:
        stream = yt_obj.streams.get_by_itag(139)
    except Exception as e:
        print(vid, "Stopping download because of Exception", e)
        return False
    stream.download(output_path = location + vid + "/", filename = "audio.mp4")
    print(vid, "Audio downloaded")
    
    print(vid, "Found captions for", list(yt_obj.captions.keys()))
    for caption in yt_obj.captions:
        if "en" in caption.code:
            a_en_caption = caption.json_captions
            json.dump(a_en_caption, open(location + vid + "/caption-" + caption.code + ".json", 'w'))
            print(vid, "Downloaded", caption.code, "captions")
    
    existing_videos.add(yt_obj.video_id)

# %%
from pytube import Search

def deep_search(search_term, existing_videos, depth = 3):
    print("Search", search_term, "Performing search at depth", depth)
    search = Search(search_term)
    search.results
    for _ in range(depth - 1):
        search.get_next_results()
        
    print("Search", search_term, "Found", len(search.results), "videos")
        
    for yt in search.results:
        attempt_download(yt, existing_videos)

# %%
from concurrent.futures import ThreadPoolExecutor

existing_videos = {x for x in os.listdir("dataset/")}
print("Starting with " + str(len(existing_videos)) + " videos")

search_terms = ["Joe Biden", "Kamala Harris", "Donald Trump", "Mike Pence", "Ron DeSantis"]

def perform_search(search_term):
    deep_search(search_term, existing_videos, depth=3)

    
with ThreadPoolExecutor(max_workers = 5) as executor:
    executor.map(perform_search, search_terms)

print("Ending with " + str(len(existing_videos)) + " videos")
# Out:
# Starting with 222 videos
# Search Joe Biden Performing search at depth 3
# Search Kamala Harris Performing search at depth 3
# Search Donald Trump Performing search at depth 3
# Search Mike Pence Performing search at depth 3
# Search Ron DeSantis Performing search at depth 3
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Joe Biden
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Kamala Harris
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search Joe Biden Found 55 videos
# h9FzYgiES84 attempt_download called
# h9FzYgiES84 Skipping, found existing folder.
# Lf6FTNSuZfM attempt_download called
# Lf6FTNSuZfM Skipping, found existing folder.
# 5NW2EEyyYxs attempt_download called
# 5NW2EEyyYxs Skipping, found existing folder.
# H_zelA-F9Ss attempt_download called
# Search Mike Pence Found 58 videos
# Ti8ipMVBf5Y attempt_download called
# Ti8ipMVBf5Y Skipping, found existing folder.
# ZrA9acvG6ck attempt_download called
# ZrA9acvG6ck Skipping, found existing folder.
# B9ykN0RKDQY attempt_download called
# B9ykN0RKDQY Skipping, found existing folder.
# _lD_biUbmaQ attempt_download called
# _lD_biUbmaQ Skipping, found existing folder.
# PHTCH1nA-eQ attempt_download called
# PHTCH1nA-eQ Skipping, found existing folder.
# -Fs0XjuFq5A attempt_download called
# -Fs0XjuFq5A Skipping, found existing folder.
# Gb-mzaOvexE attempt_download called
# Gb-mzaOvexE Skipping, found existing folder.
# Eum23dPZ-Yg attempt_download called
# Eum23dPZ-Yg Skipping, found existing folder.
# 0R0GUtaXh0A attempt_download called
# 0R0GUtaXh0A Skipping, found existing folder.
# LJZ1RijOmCk attempt_download called
# LJZ1RijOmCk Skipping, found existing folder.
# z6iCzaHT8ZY attempt_download called
# z6iCzaHT8ZY Skipping, found existing folder.
# Nk89WYi-2B0 attempt_download called
# Nk89WYi-2B0 Skipping, found existing folder.
# _IIKGN3qsXs attempt_download called
# _IIKGN3qsXs Skipping, found existing folder.
# sBFyeGYrTF4 attempt_download called
# sBFyeGYrTF4 Skipping, found existing folder.
# XRTZiZZEd0Y attempt_download called
# XRTZiZZEd0Y Skipping, found existing folder.
# 1XKxfaRNGR4 attempt_download called
# 1XKxfaRNGR4 Skipping, found existing folder.
# XEZpDcZK7oo attempt_download called
# XEZpDcZK7oo Skipping, found existing folder.
# v3tVG9XMQ5c attempt_download called
# v3tVG9XMQ5c Skipping, found existing folder.
# 1QQ1eNyG1Fo attempt_download called
# 1QQ1eNyG1Fo Skipping, found existing folder.
# 9foQYGJ8Ug8 attempt_download called
# Search Ron DeSantis Found 57 videos
# PE_WvYscN44 attempt_download called
# PE_WvYscN44 Skipping, found existing folder.
# MHhoX8kMH1o attempt_download called
# MHhoX8kMH1o Skipping, found existing folder.
# Sd_AcwVFlkI attempt_download called
# Sd_AcwVFlkI Skipping, found existing folder.
# djT5HHcTk10 attempt_download called
# djT5HHcTk10 Skipping, found existing folder.
# qK0pKPyH8nA attempt_download called
# qK0pKPyH8nA Skipping, found existing folder.
# TcaC0sNrXE8 attempt_download called
# TcaC0sNrXE8 Skipping, found existing folder.
# CzSc9Uow2O0 attempt_download called
# CzSc9Uow2O0 Skipping, found existing folder.
# Uv59mXBUzLk attempt_download called
# Uv59mXBUzLk Skipping, found existing folder.
# HZ5iBKUXFro attempt_download called
# HZ5iBKUXFro Skipping, found existing folder.
# k5vf87IlqFU attempt_download called
# k5vf87IlqFU Skipping, found existing folder.
# lNb6ftILwtM attempt_download called
# lNb6ftILwtM Skipping, found existing folder.
# SejsKJjfYdA attempt_download called
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Kamala Harris
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Kamala Harris
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Search Donald Trump Found 53 videos
# ZOzguIxm1Ps attempt_download called
# ZOzguIxm1Ps Skipping, found existing folder.
# 1bXi-GKzdfk attempt_download called
# Search Kamala Harris Found 55 videos
# XudEcLXg72I attempt_download called
# XudEcLXg72I Skipping, found existing folder.
# AaDrcsp9vN4 attempt_download called
# AaDrcsp9vN4 Skipping, found existing folder.
# Vya_cl3kWRI attempt_download called
# Vya_cl3kWRI Skipping, found existing folder.
# fVbMWFGy4HM attempt_download called
# fVbMWFGy4HM Skipping, found existing folder.
# 6pfH2YS9Hd8 attempt_download called
# 6pfH2YS9Hd8 Skipping, found existing folder.
# Wh9laE-XO4U attempt_download called
# Wh9laE-XO4U Skipping, found existing folder.
# 6Ti2gDCTlFc attempt_download called
# 6Ti2gDCTlFc Skipping, found existing folder.
# Ak3S33zdxIw attempt_download called
# Ak3S33zdxIw Skipping, found existing folder.
# B5cu3zJSIV4 attempt_download called
# B5cu3zJSIV4 Skipping, found existing folder.
# xz7rNOAFkgE attempt_download called
# xz7rNOAFkgE Skipping, found existing folder.
# p484Bdgza3Y attempt_download called
# p484Bdgza3Y Skipping, found existing folder.
# U3tcsVEMts0 attempt_download called
# U3tcsVEMts0 Skipping, found existing folder.
# szh4FkD25VU attempt_download called
# szh4FkD25VU Skipping, found existing folder.
# HGLyjaIlhO0 attempt_download called
# HGLyjaIlhO0 Skipping, found existing folder.
# Ua9UuC2mE5I attempt_download called
# 1bXi-GKzdfk Stopping download because of Exception 1bXi-GKzdfk is streaming live and cannot be loaded
# h9FzYgiES84 attempt_download called
# h9FzYgiES84 Skipping, found existing folder.
# NimheYoq9Lw attempt_download called
# SejsKJjfYdA Audio downloaded
# SejsKJjfYdA Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# H_zelA-F9SsSejsKJjfYdA Downloaded a.en captions
#  Audio downloaded
# H_zelA-F9Ss Found captions for [<Caption lang="English" code="en">, <Caption lang="English (United States)" code="en-US">]
# H_zelA-F9Ss Downloaded en captions
# H_zelA-F9Ss Downloaded en-US captions
# ilNBDp-xArc attempt_download called
# SejsKJjfYdA Downloaded en.uYU-mmqFLq8 captions
# Ua9UuC2mE5I Audio downloaded
# Ua9UuC2mE5I Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# Ua9UuC2mE5I Downloaded a.en captions
# UhOhW1AeP5k attempt_download called
# UhOhW1AeP5k Skipping, found existing folder.
# q4W-3tw4k44 attempt_download called
# q4W-3tw4k44 Skipping, found existing folder.
# iST-AsOBkdg attempt_download called
# SejsKJjfYdA Downloaded en.JkeT_87f4cc captions
# NimheYoq9Lw Audio downloaded
# NimheYoq9Lw Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English (United States)" code="en-US">]
# SejsKJjfYdA Downloaded en.nP7-2PuUl7o captions
# z1YP_zZJFXs attempt_download called
# z1YP_zZJFXs Skipping, found existing folder.
# iEzJGG6D51A attempt_download called
# NimheYoq9Lw Downloaded a.en captions
# 9foQYGJ8Ug8 Audio downloaded
# 9foQYGJ8Ug8 Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# NimheYoq9Lw Downloaded en.uYU-mmqFLq8 captions
# 9foQYGJ8Ug8 Downloaded a.en captions
# tXFqTGBty1w attempt_download called
# tXFqTGBty1w Skipping, found existing folder.
# zu-Fn-DUhGs attempt_download called
# zu-Fn-DUhGs Skipping, found existing folder.
# t_G0ia3JOVs attempt_download called
# NimheYoq9Lw Downloaded en.JkeT_87f4cc captions
# NimheYoq9Lw Downloaded en-US captions
# KxTjzhwii60 attempt_download called
# ilNBDp-xArc Audio downloaded
# ilNBDp-xArc Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# ilNBDp-xArciST-AsOBkdg Audio downloaded
# iST-AsOBkdg Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
#  Downloaded a.en captions
# kd3hSSRVDso attempt_download called
# kd3hSSRVDso Skipping, found existing folder.
# pgIG-bBcguk attempt_download called
# pgIG-bBcguk Skipping, found existing folder.
# fp-2gUTn--4 attempt_download called
# fp-2gUTn--4 Skipping, found existing folder.
# _wq4b18Eayk attempt_download called
# _wq4b18Eayk Skipping, found existing folder.
# ChjibtX0UzU attempt_download called
# iST-AsOBkdg Downloaded a.en captions
# M2v_uRY6yPw attempt_download called
# M2v_uRY6yPw Skipping, found existing folder.
# bdGasPk9E20 attempt_download called
# bdGasPk9E20 Skipping, found existing folder.
# 8Jc-kL22fQU attempt_download called
# 8Jc-kL22fQU Skipping, found existing folder.
# 9Rjbs177Obs attempt_download called
# 9Rjbs177Obs Skipping, found existing folder.
# PLLkmW5Ymqg attempt_download called
# PLLkmW5Ymqg Skipping, found existing folder.
# h-aqTtywDDI attempt_download called
# h-aqTtywDDI Skipping, found existing folder.
# _2wMKdMuJoM attempt_download called
# _2wMKdMuJoM Skipping, found existing folder.
# wbzmuhRJdqw attempt_download called
# wbzmuhRJdqw Skipping, found existing folder.
# XipylAY9LP4 attempt_download called
# XipylAY9LP4 Skipping, found existing folder.
# -Pg1nNL5wVE attempt_download called
# -Pg1nNL5wVE Skipping, found existing folder.
# KaN2GMUP6Z0 attempt_download called
# KaN2GMUP6Z0 Skipping, found existing folder.
# 7DqPWA9wijk attempt_download called
# 7DqPWA9wijk Skipping, found existing folder.
# RArcOYVADqQ attempt_download called
# RArcOYVADqQ Skipping, found existing folder.
# ekHQMMNNho0 attempt_download called
# ekHQMMNNho0 Skipping, found existing folder.
# xSHNjHjsKWE attempt_download called
# xSHNjHjsKWE Skipping, found existing folder.
# tXFqTGBty1w attempt_download called
# tXFqTGBty1w Skipping, found existing folder.
# GSyuoBCPgSc attempt_download called
# GSyuoBCPgSc Skipping, found existing folder.
# B5cu3zJSIV4 attempt_download called
# B5cu3zJSIV4 Skipping, found existing folder.
# umCfswT-uE0 attempt_download called
# umCfswT-uE0 Skipping, found existing folder.
# ZZQUktyNpKo attempt_download called
# ZZQUktyNpKo Skipping, found existing folder.
# Q3sa3A2W7DI attempt_download called
# iEzJGG6D51A Audio downloaded
# iEzJGG6D51A Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# Q3sa3A2W7DI Stopping download because of Exception Q3sa3A2W7DI is age restricted, and can't be accessed without logging in.
# c5X62Wy6Kx4 attempt_download called
# c5X62Wy6Kx4 Skipping, found existing folder.
# CqaQ26BJXMs attempt_download called
# CqaQ26BJXMs Skipping, found existing folder.
# mk9iHIqOXhU attempt_download called
# mk9iHIqOXhU Skipping, found existing folder.
# Ax7LlQDSW_Q attempt_download called
# Ax7LlQDSW_Q Skipping, found existing folder.
# IuxonjJ5WHs attempt_download called
# IuxonjJ5WHs Skipping, found existing folder.
# 0O-7sjfgYqw attempt_download called
# 0O-7sjfgYqw Skipping, found existing folder.
# OWaQhdBZmw0 attempt_download called
# OWaQhdBZmw0 Skipping, found existing folder.
# 72vUngNA9RM attempt_download called
# 72vUngNA9RM Skipping, found existing folder.
# q7TCqVoIgwM attempt_download called
# q7TCqVoIgwM Skipping, found existing folder.
# Dr3tRna3t0U attempt_download called
# Dr3tRna3t0U Skipping, found existing folder.
# 3AGkznPIZd4 attempt_download called
# 3AGkznPIZd4 Skipping, found existing folder.
# RKDC3u8bgyk attempt_download called
# RKDC3u8bgyk Skipping, found existing folder.
# KYr_utdI75Q attempt_download called
# KYr_utdI75Q Skipping, found existing folder.
# Be_k3cH0c9Q attempt_download called
# Be_k3cH0c9Q Skipping, found existing folder.
# wdmLlw1M2qA attempt_download called
# wdmLlw1M2qA Skipping, found existing folder.
# FnaRbUeXsaI attempt_download called
# iEzJGG6D51A Downloaded a.en captions
# gj5li0CHpic attempt_download called
# gj5li0CHpic Skipping, found existing folder.
# cbMMdZs2-CI attempt_download called
# cbMMdZs2-CI Skipping, found existing folder.
# iwiwW28_eYc attempt_download called
# iwiwW28_eYc Skipping, found existing folder.
# kNho4OdYntU attempt_download called
# kNho4OdYntU Skipping, found existing folder.
# JCIa1Ychu2g attempt_download called
# JCIa1Ychu2g Skipping, found existing folder.
# koM2sEv-DoA attempt_download called
# koM2sEv-DoA Skipping, found existing folder.
# N3_OLeK9wdU attempt_download called
# ChjibtX0UzU Audio downloaded
# ChjibtX0UzU Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English (United States)" code="en-US">, <Caption lang="Spanish" code="es">]
# ChjibtX0UzU Downloaded a.en captions
# ChjibtX0UzU Downloaded en-US captions
# s2PHzMCJb0M attempt_download called
# s2PHzMCJb0M Skipping, found existing folder.
# L1YOKDlP254 attempt_download called
# L1YOKDlP254 Audio downloaded
# L1YOKDlP254 Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# L1YOKDlP254 Downloaded a.en captions
# LKhfhMMEHU4 attempt_download called
# LKhfhMMEHU4 Skipping, found existing folder.
# qmX7y8B9kTU attempt_download called
# qmX7y8B9kTU Skipping, found existing folder.
# FXWfHq9TjAk attempt_download called
# FXWfHq9TjAk Skipping, found existing folder.
# oc7bn-QLv6E attempt_download called
# oc7bn-QLv6E Skipping, found existing folder.
# Cn9Zo0VE1UY attempt_download called
# Cn9Zo0VE1UY Skipping, found existing folder.
# 9rCevF2fCC8 attempt_download called
# 9rCevF2fCC8 Skipping, found existing folder.
# nBLc8cOxpIQ attempt_download called
# nBLc8cOxpIQ Skipping, found existing folder.
# 1UPyZHMpsKU attempt_download called
# FnaRbUeXsaI Audio downloaded
# FnaRbUeXsaI Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# FnaRbUeXsaI Downloaded a.en captions
# t_G0ia3JOVs Audio downloaded
# t_G0ia3JOVs Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">]
# t_G0ia3JOVs Downloaded a.en captions
# t_G0ia3JOVs Downloaded en.uYU-mmqFLq8 captions
# KxTjzhwii60 Audio downloaded
# KxTjzhwii60 Found captions for []
# 9Vbtq6rjT5o attempt_download called
# 1UPyZHMpsKU Audio downloaded
# 1UPyZHMpsKU Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# 1UPyZHMpsKU Downloaded a.en captions
# ueqko-4LGLg attempt_download called
# ueqko-4LGLg Skipping, found existing folder.
# qtSc6koEPZo attempt_download called
# qtSc6koEPZo Skipping, found existing folder.
# nsoAkBWfPJs attempt_download called
# t_G0ia3JOVs Downloaded en.JkeT_87f4cc captions
# lU2wL0vIfGg attempt_download called
# 9Vbtq6rjT5o Audio downloaded
# 9Vbtq6rjT5o Found captions for [<Caption lang="English" code="en">, <Caption lang="English (auto-generated)" code="a.en">]
# 9Vbtq6rjT5o Downloaded en captions
# 9Vbtq6rjT5o Downloaded a.en captions
# FR0cRnDwhaQ attempt_download called
# nsoAkBWfPJs Audio downloaded
# nsoAkBWfPJs Found captions for []
# 0AN2pFwawj8 attempt_download called
# 0AN2pFwawj8 Skipping, found existing folder.
# k37NbQSP29I attempt_download called
# k37NbQSP29I Skipping, found existing folder.
# cr61qRl1Gtk attempt_download called
# cr61qRl1Gtk Skipping, found existing folder.
# JvybfjJUZY0 attempt_download called
# JvybfjJUZY0 Skipping, found existing folder.
# QuYLHok8ZyY attempt_download called
# QuYLHok8ZyY Skipping, found existing folder.
# GcVTzgZyGro attempt_download called
# GcVTzgZyGro Skipping, found existing folder.
# lwPzRIy2pU8 attempt_download called
# lwPzRIy2pU8 Skipping, found existing folder.
# S8oP5zcbRTw attempt_download called
# S8oP5zcbRTw Skipping, found existing folder.
# QvvG9nCe0lI attempt_download called
# QvvG9nCe0lI Skipping, found existing folder.
# YicZDOimR4U attempt_download called
# YicZDOimR4U Skipping, found existing folder.
# dB0Qem2I4pI attempt_download called
# N3_OLeK9wdU Audio downloaded
# N3_OLeK9wdU Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# N3_OLeK9wdU Downloaded a.en captions
# 5FzPB8yKkQU attempt_download called
# 5FzPB8yKkQU Skipping, found existing folder.
# l8J_03pfy-w attempt_download called
# lU2wL0vIfGg Audio downloaded
# lU2wL0vIfGg Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# lU2wL0vIfGg Downloaded a.en captions
# lU2wL0vIfGg Downloaded en.uYU-mmqFLq8 captions
# lU2wL0vIfGg Downloaded en.JkeT_87f4cc captions
# lU2wL0vIfGg Downloaded en.nP7-2PuUl7o captions
# -jiiFZohnIg attempt_download called
# -jiiFZohnIg Skipping, found existing folder.
# sUe2OhHMfUQ attempt_download called
# sUe2OhHMfUQ Skipping, found existing folder.
# mfI-7rGklVE attempt_download called
# mfI-7rGklVE Skipping, found existing folder.
# _LJnm2r6huQ attempt_download called
# FR0cRnDwhaQ Audio downloaded
# FR0cRnDwhaQ Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# FR0cRnDwhaQ Downloaded a.en captions
# 1LGpgQS4Di8 attempt_download called
# l8J_03pfy-w Audio downloaded
# l8J_03pfy-w Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# l8J_03pfy-w Downloaded a.en captions
# gTX7ZKSd8Uc attempt_download called
# gTX7ZKSd8Uc Skipping, found existing folder.
# Noy6zoanz-c attempt_download called
# dB0Qem2I4pI Audio downloaded
# dB0Qem2I4pI Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# dB0Qem2I4pI Downloaded a.en captions
# XmWVQ2dGiHg attempt_download called
# XmWVQ2dGiHg Skipping, found existing folder.
# cy-0e5PNGeg attempt_download called
# cy-0e5PNGeg Skipping, found existing folder.
# NpBPm0b9deQ attempt_download called
# NpBPm0b9deQ Skipping, found existing folder.
# I6k1Ky-xygs attempt_download called
# _LJnm2r6huQ Audio downloaded
# _LJnm2r6huQ Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# 1LGpgQS4Di8 Audio downloaded
# 1LGpgQS4Di8 Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# _LJnm2r6huQ Downloaded a.en captions
# xeel3PqDGek attempt_download called
# 1LGpgQS4Di8 Downloaded a.en captions
# 1LGpgQS4Di8 Downloaded en.uYU-mmqFLq8 captions
# 1LGpgQS4Di8 Downloaded en.JkeT_87f4cc captions
# Noy6zoanz-c Audio downloaded
# Noy6zoanz-c Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# 1LGpgQS4Di8 Downloaded en.nP7-2PuUl7o captions
# 1L-HLmdVWUA attempt_download called
# Noy6zoanz-c Downloaded a.en captions
# uhNQwr4FKk4 attempt_download called
# uhNQwr4FKk4 Skipping, found existing folder.
# 3ybSWPd5L8k attempt_download called
# 3ybSWPd5L8k Skipping, found existing folder.
# uG_Sd8wCgz8 attempt_download called
# uG_Sd8wCgz8 Skipping, found existing folder.
# r-RmXErVGRQ attempt_download called
# r-RmXErVGRQ Skipping, found existing folder.
# ZRQMbUzEMf4 attempt_download called
# ZRQMbUzEMf4 Skipping, found existing folder.
# E5N2VtvhPWg attempt_download called
# E5N2VtvhPWg Skipping, found existing folder.
# WTdyV2H4heQ attempt_download called
# WTdyV2H4heQ Skipping, found existing folder.
# COzAPK5XQG4 attempt_download called
# xeel3PqDGek Stopping download because of Exception xeel3PqDGek is age restricted, and can't be accessed without logging in.
# XGG_pQj02HY attempt_download called
# XGG_pQj02HY Skipping, found existing folder.
# s5eJx5Nkv18 attempt_download called
# s5eJx5Nkv18 Skipping, found existing folder.
# OqZpQTPgIw8 attempt_download called
# OqZpQTPgIw8 Skipping, found existing folder.
# ROb64hDVl1o attempt_download called
# ROb64hDVl1o Skipping, found existing folder.
# C4tivPraEBk attempt_download called
# C4tivPraEBk Skipping, found existing folder.
# WkUZ87NPB7o attempt_download called
# WkUZ87NPB7o Skipping, found existing folder.
# jbQmmTm7iPU attempt_download called
# I6k1Ky-xygs Audio downloaded
# I6k1Ky-xygs Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# I6k1Ky-xygs Downloaded a.en captions
# ggwnjtTwM6I attempt_download called
# ggwnjtTwM6I Skipping, found existing folder.
# TM5OaOqAdQQ attempt_download called
# TM5OaOqAdQQ Skipping, found existing folder.
# Vs3lFBlWu94 attempt_download called
# Vs3lFBlWu94 Skipping, found existing folder.
# _ctthyYjglw attempt_download called
# _ctthyYjglw Skipping, found existing folder.
# 1aI_jijvr2s attempt_download called
# 1aI_jijvr2s Skipping, found existing folder.
# qLaTpOOKOzI attempt_download called
# qLaTpOOKOzI Skipping, found existing folder.
# EhPhgUt9rrs attempt_download called
# EhPhgUt9rrs Skipping, found existing folder.
# XX6Y5Sb--Jc attempt_download called
# XX6Y5Sb--Jc Skipping, found existing folder.
# CH335fMo0Yw attempt_download called
# 1L-HLmdVWUA Audio downloaded
# 1L-HLmdVWUA Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# 1L-HLmdVWUA Downloaded a.en captions
# pFw97kQLt5I attempt_download called
# COzAPK5XQG4 Audio downloaded
# COzAPK5XQG4 Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# COzAPK5XQG4 Downloaded a.en captions
# SMkk7dk4cuQ attempt_download called
# SMkk7dk4cuQ Skipping, found existing folder.
# WixdQXQzKaA attempt_download called
# WixdQXQzKaA Skipping, found existing folder.
# zPwsZl9f5UM attempt_download called
# zPwsZl9f5UM Skipping, found existing folder.
# HezhVpAJIhU attempt_download called
# HezhVpAJIhU Skipping, found existing folder.
# 9kvSTyC9Hnk attempt_download called
# 9kvSTyC9Hnk Skipping, found existing folder.
# rXJIgW1niZA attempt_download called
# rXJIgW1niZA Skipping, found existing folder.
# saZfcclFdIA attempt_download called
# saZfcclFdIA Skipping, found existing folder.
# pLZgBYPiJ24 attempt_download called
# CH335fMo0Yw Audio downloaded
# CH335fMo0Yw Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# CH335fMo0Yw Downloaded a.en captions
# SuQunX2Oyl8 attempt_download called
# SuQunX2Oyl8 Skipping, found existing folder.
# R6nwZdOGpXk attempt_download called
# jbQmmTm7iPU Audio downloaded
# jbQmmTm7iPU Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# jbQmmTm7iPU Downloaded a.en captions
# iR3HLpxriVY attempt_download called
# iR3HLpxriVY Skipping, found existing folder.
# Bunw130cWeE attempt_download called
# pLZgBYPiJ24 Audio downloaded
# pLZgBYPiJ24 Found captions for [<Caption lang="English - en" code="en.nP7-2PuUl7o">, <Caption lang="English (United States)" code="en-US">]
# pLZgBYPiJ24 Downloaded en.nP7-2PuUl7o captions
# pFw97kQLt5I Audio downloaded
# pFw97kQLt5I Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# pLZgBYPiJ24 Downloaded en-US captions
# LT0Rx1hUaew attempt_download called
# LT0Rx1hUaew Skipping, found existing folder.
# _6V-31kSNBY attempt_download called
# _6V-31kSNBY Skipping, found existing folder.
# XfW5AaoaQ-k attempt_download called
# XfW5AaoaQ-k Skipping, found existing folder.
# BS5Ffg2ipwo attempt_download called
# BS5Ffg2ipwo Skipping, found existing folder.
# 0_d6GKg75cQ attempt_download called
# pFw97kQLt5I Downloaded a.en captions
# R6nwZdOGpXk Audio downloaded
# R6nwZdOGpXk Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# R6nwZdOGpXk Downloaded a.en captions
# vw7-lKfSnAY attempt_download called
# pFw97kQLt5I Downloaded en.uYU-mmqFLq8 captions
# pFw97kQLt5I Downloaded en.JkeT_87f4cc captions
# pFw97kQLt5I Downloaded en.nP7-2PuUl7o captions
# gupii3PWa1A attempt_download called
# Bunw130cWeE Audio downloaded
# Bunw130cWeE Found captions for []
# VtdXsfMt8tI attempt_download called
# VtdXsfMt8tI Skipping, found existing folder.
# d8BaqxfkGOU attempt_download called
# d8BaqxfkGOU Skipping, found existing folder.
# jS6sfwrOfWc attempt_download called
# jS6sfwrOfWc Skipping, found existing folder.
# 9oxwO__ydhM attempt_download called
# 9oxwO__ydhM Skipping, found existing folder.
# KpdKJ_5CIds attempt_download called
# KpdKJ_5CIds Skipping, found existing folder.
# 25tRDgvE-tQ attempt_download called
# 25tRDgvE-tQ Skipping, found existing folder.
# DKBVV9FfVZM attempt_download called
# DKBVV9FfVZM Skipping, found existing folder.
# fHPXisu1Uug attempt_download called
# fHPXisu1Uug Skipping, found existing folder.
# ESEo8fDCGv8 attempt_download called
# ESEo8fDCGv8 Skipping, found existing folder.
# zBSuqA4zVf0 attempt_download called
# zBSuqA4zVf0 Skipping, found existing folder.
# mIi9qv2UzCs attempt_download called
# mIi9qv2UzCs Skipping, found existing folder.
# 6WnzKU9owZA attempt_download called
# 6WnzKU9owZA Skipping, found existing folder.
# 6VX0exiKWFk attempt_download called
# 6VX0exiKWFk Skipping, found existing folder.
# fAWoCuDyEr8 attempt_download called
# fAWoCuDyEr8 Skipping, found existing folder.
# MpCoVxa_kVM attempt_download called
# MpCoVxa_kVM Skipping, found existing folder.
# SslliGRyn3M attempt_download called
# SslliGRyn3M Skipping, found existing folder.
# IwzzaNHb-ts attempt_download called
# IwzzaNHb-ts Skipping, found existing folder.
# 4Iw6xPI3N_I attempt_download called
# 4Iw6xPI3N_I Skipping, found existing folder.
# CDa0OLUq1I0 attempt_download called
# CDa0OLUq1I0 Skipping, found existing folder.
# jtLGIQjUTZQ attempt_download called
# jtLGIQjUTZQ Skipping, found existing folder.
# 0_d6GKg75cQ Audio downloaded
# 0_d6GKg75cQ Found captions for [<Caption lang="English" code="en">]
# 0_d6GKg75cQ Downloaded en captions
# uQi9LDcbFZE attempt_download called
# vw7-lKfSnAY Audio downloaded
# vw7-lKfSnAY Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# vw7-lKfSnAY Downloaded a.en captions
# njXjz8VHCNE attempt_download called
# njXjz8VHCNE Skipping, found existing folder.
# unrxZtm-Dxc attempt_download called
# unrxZtm-Dxc Skipping, found existing folder.
# Wh9laE-XO4U attempt_download called
# Wh9laE-XO4U Skipping, found existing folder.
# j0oIrAy00Bo attempt_download called
# j0oIrAy00Bo Skipping, found existing folder.
# Vf9kXOyHkHA attempt_download called
# Vf9kXOyHkHA Audio downloaded
# Vf9kXOyHkHA Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# Vf9kXOyHkHA Downloaded a.en captions
# uQi9LDcbFZE Audio downloaded
# uQi9LDcbFZE Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# uQi9LDcbFZE Downloaded a.en captions
# XKHwo62Z4To attempt_download called
# XKHwo62Z4To Skipping, found existing folder.
# rIS5YK_l2r4 attempt_download called
# rIS5YK_l2r4 Skipping, found existing folder.
# -CXBSpVtuxI attempt_download called
# -CXBSpVtuxI Skipping, found existing folder.
# cjdYdw2AXsE attempt_download called
# cjdYdw2AXsE Skipping, found existing folder.
# 7Are-V5o0Ks attempt_download called
# gupii3PWa1A Audio downloaded
# gupii3PWa1A Found captions for []
# JJWluUYLA-I attempt_download called
# 7Are-V5o0Ks Audio downloaded
# 7Are-V5o0Ks Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English (United States)" code="en-US">]
# 7Are-V5o0Ks Downloaded a.en captions
# 7Are-V5o0Ks Downloaded en.uYU-mmqFLq8 captions
# 7Are-V5o0Ks Downloaded en.JkeT_87f4cc captions
# 7Are-V5o0Ks Downloaded en-US captions
# uiYmkYTd71Q attempt_download called
# JJWluUYLA-I Audio downloaded
# JJWluUYLA-I Found captions for []
# gR6_5OlUgak attempt_download called
# gR6_5OlUgak Audio downloaded
# gR6_5OlUgak Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# gR6_5OlUgak Downloaded a.en captions
# JHJWdtPsEp0 attempt_download called
# JHJWdtPsEp0 Stopping download because of Exception JHJWdtPsEp0 is streaming live and cannot be loaded
# quzNTv83saY attempt_download called
# quzNTv83saY Stopping download because of Exception quzNTv83saY is streaming live and cannot be loaded
# _7fakQ2t8QQ attempt_download called
# uiYmkYTd71Q Audio downloaded
# uiYmkYTd71Q Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# uiYmkYTd71Q Downloaded a.en captions
# uiYmkYTd71Q Downloaded en.uYU-mmqFLq8 captions
# uiYmkYTd71Q Downloaded en.JkeT_87f4cc captions
# uiYmkYTd71Q Downloaded en.nP7-2PuUl7o captions
# Pq7s5QZnrAM attempt_download called
# _7fakQ2t8QQ Audio downloaded
# _7fakQ2t8QQ Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# _7fakQ2t8QQ Downloaded a.en captions
# r1jlOj3M0XQ attempt_download called
# Pq7s5QZnrAM Audio downloaded
# Pq7s5QZnrAM Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English (United States)" code="en-US">]
# r1jlOj3M0XQ Audio downloaded
# r1jlOj3M0XQ Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# Pq7s5QZnrAM Downloaded a.en captions
# r1jlOj3M0XQ Downloaded a.en captions
# dwlQS4xxCaI attempt_download called
# Pq7s5QZnrAM Downloaded en.uYU-mmqFLq8 captions
# Pq7s5QZnrAM Downloaded en.JkeT_87f4cc captions
# Pq7s5QZnrAM Downloaded en-US captions
# -Mb8OzR4JjQ attempt_download called
# dwlQS4xxCaI Audio downloaded
# dwlQS4xxCaI Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# dwlQS4xxCaI Downloaded a.en captions
# OSus3lMyEQA attempt_download called
# -Mb8OzR4JjQ Audio downloaded
# -Mb8OzR4JjQ Found captions for [<Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">]
# -Mb8OzR4JjQ Downloaded en.uYU-mmqFLq8 captions
# -Mb8OzR4JjQ Downloaded en.JkeT_87f4cc captions
# SIyo2TH1IsQ attempt_download called
# OSus3lMyEQA Audio downloaded
# OSus3lMyEQA Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# OSus3lMyEQA Downloaded a.en captions
# MI7x9WepEQU attempt_download called
# MI7x9WepEQU Audio downloaded
# MI7x9WepEQU Found captions for []
# th8W7c86KFQ attempt_download called
# SIyo2TH1IsQ Audio downloaded
# SIyo2TH1IsQ Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# SIyo2TH1IsQ Downloaded a.en captions
# SIyo2TH1IsQ Downloaded en.uYU-mmqFLq8 captions
# SIyo2TH1IsQ Downloaded en.nP7-2PuUl7o captions
# SP6nP4lk5Uw attempt_download called
# SP6nP4lk5Uw Skipping, found existing folder.
# th8W7c86KFQ Audio downloaded
# th8W7c86KFQ Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# th8W7c86KFQ Downloaded a.en captions
# ZP8dbbw7zEw attempt_download called
# ZP8dbbw7zEw Audio downloaded
# ZP8dbbw7zEw Found captions for []
# sbezgYVvyng attempt_download called
# sbezgYVvyng Audio downloaded
# sbezgYVvyng Found captions for []
# 74TFS8r_SMI attempt_download called
# 74TFS8r_SMI Audio downloaded
# 74TFS8r_SMI Found captions for []
# unA5OJxq6bs attempt_download called
# unA5OJxq6bs Audio downloaded
# unA5OJxq6bs Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# unA5OJxq6bs Downloaded a.en captions
# unA5OJxq6bs Downloaded en.uYU-mmqFLq8 captions
# unA5OJxq6bs Downloaded en.JkeT_87f4cc captions
# unA5OJxq6bs Downloaded en.nP7-2PuUl7o captions
# wh8Xt0gx_E4 attempt_download called
# wh8Xt0gx_E4 Audio downloaded
# wh8Xt0gx_E4 Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# wh8Xt0gx_E4 Downloaded a.en captions
# rzad4yv6lys attempt_download called
# rzad4yv6lys Audio downloaded
# rzad4yv6lys Found captions for [<Caption lang="English" code="en">]
# rzad4yv6lys Downloaded en captions
# NHb0OJa443g attempt_download called
# NHb0OJa443g Audio downloaded
# NHb0OJa443g Found captions for []
# 8MdWBzc487k attempt_download called
# 8MdWBzc487k Audio downloaded
# 8MdWBzc487k Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# 8MdWBzc487k Downloaded a.en captions
# n-PHMPCC-SY attempt_download called
# n-PHMPCC-SY Audio downloaded
# n-PHMPCC-SY Found captions for []
# 0VN7V-6lxyM attempt_download called
# 0VN7V-6lxyM Audio downloaded
# 0VN7V-6lxyM Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# 0VN7V-6lxyM Downloaded a.en captions
# wSp5STJKp_o attempt_download called
# wSp5STJKp_o Audio downloaded
# wSp5STJKp_o Found captions for [<Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">]
# wSp5STJKp_o Downloaded en.uYU-mmqFLq8 captions
# wSp5STJKp_o Downloaded en.JkeT_87f4cc captions
# hw2fOryK5rs attempt_download called
# hw2fOryK5rs Audio downloaded
# hw2fOryK5rs Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# hw2fOryK5rs Downloaded a.en captions
# WGXsIBkbwso attempt_download called
# WGXsIBkbwso Stopping download because of Exception WGXsIBkbwso is streaming live and cannot be loaded
# fx9DANFmZtA attempt_download called
# fx9DANFmZtA Audio downloaded
# fx9DANFmZtA Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# fx9DANFmZtA Downloaded a.en captions
# fx9DANFmZtA Downloaded en.uYU-mmqFLq8 captions
# fx9DANFmZtA Downloaded en.JkeT_87f4cc captions
# fx9DANFmZtA Downloaded en.nP7-2PuUl7o captions
# vXl7B_O1FM4 attempt_download called
# vXl7B_O1FM4 Audio downloaded
# vXl7B_O1FM4 Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# vXl7B_O1FM4 Downloaded a.en captions
# sgJNtt9ULq4 attempt_download called
# sgJNtt9ULq4 Audio downloaded
# sgJNtt9ULq4 Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# sgJNtt9ULq4 Downloaded a.en captions
# sgJNtt9ULq4 Downloaded en.uYU-mmqFLq8 captions
# sgJNtt9ULq4 Downloaded en.nP7-2PuUl7o captions
# ooXYrUW-CQc attempt_download called
# ooXYrUW-CQc Audio downloaded
# ooXYrUW-CQc Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# ooXYrUW-CQc Downloaded a.en captions
# PQIV-ce7eAw attempt_download called
# PQIV-ce7eAw Audio downloaded
# PQIV-ce7eAw Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# PQIV-ce7eAw Downloaded a.en captions
# LyXZ6QFFcYw attempt_download called
# LyXZ6QFFcYw Audio downloaded
# LyXZ6QFFcYw Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# LyXZ6QFFcYw Downloaded a.en captions
# LyXZ6QFFcYw Downloaded en.uYU-mmqFLq8 captions
# LyXZ6QFFcYw Downloaded en.JkeT_87f4cc captions
# LyXZ6QFFcYw Downloaded en.nP7-2PuUl7o captions
# 0pbYSp0ROmo attempt_download called
# 0pbYSp0ROmo Audio downloaded
# 0pbYSp0ROmo Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# 0pbYSp0ROmo Downloaded a.en captions
# 0pbYSp0ROmo Downloaded en.uYU-mmqFLq8 captions
# 0pbYSp0ROmo Downloaded en.JkeT_87f4cc captions
# 0pbYSp0ROmo Downloaded en.nP7-2PuUl7o captions
# Bt0z0kmPOwc attempt_download called
# Bt0z0kmPOwc Audio downloaded
# Bt0z0kmPOwc Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# Bt0z0kmPOwc Downloaded a.en captions
# BKHbd3rstvQ attempt_download called
# BKHbd3rstvQ Audio downloaded
# BKHbd3rstvQ Found captions for [<Caption lang="English (United States)" code="en-US">]
# BKHbd3rstvQ Downloaded en-US captions
# dIg_CTLlpfs attempt_download called
# dIg_CTLlpfs Audio downloaded
# dIg_CTLlpfs Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# dIg_CTLlpfs Downloaded a.en captions
# Sc3Z61lnDO8 attempt_download called
# Sc3Z61lnDO8 Audio downloaded
# Sc3Z61lnDO8 Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# Sc3Z61lnDO8 Downloaded a.en captions
# DPi5dgYn2rU attempt_download called
# DPi5dgYn2rU Audio downloaded
# DPi5dgYn2rU Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# DPi5dgYn2rU Downloaded a.en captions
# UfnLSnH1ZGE attempt_download called
# UfnLSnH1ZGE Audio downloaded
# UfnLSnH1ZGE Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# UfnLSnH1ZGE Downloaded a.en captions
# UfnLSnH1ZGE Downloaded en.uYU-mmqFLq8 captions
# UfnLSnH1ZGE Downloaded en.JkeT_87f4cc captions
# UfnLSnH1ZGE Downloaded en.nP7-2PuUl7o captions
# Ftd2NMWsjRs attempt_download called
# Ftd2NMWsjRs Audio downloaded
# Ftd2NMWsjRs Found captions for [<Caption lang="English (auto-generated)" code="a.en">, <Caption lang="English - CC1" code="en.uYU-mmqFLq8">, <Caption lang="English - DTVCC1" code="en.JkeT_87f4cc">, <Caption lang="English - en" code="en.nP7-2PuUl7o">]
# Ftd2NMWsjRs Downloaded a.en captions
# Ftd2NMWsjRs Downloaded en.uYU-mmqFLq8 captions
# Ftd2NMWsjRs Downloaded en.JkeT_87f4cc captions
# Ftd2NMWsjRs Downloaded en.nP7-2PuUl7o captions
# W35_RKKmfew attempt_download called
# W35_RKKmfew Audio downloaded
# W35_RKKmfew Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# W35_RKKmfew Downloaded a.en captions
# TQFw_PdbuO8 attempt_download called
# TQFw_PdbuO8 Audio downloaded
# TQFw_PdbuO8 Found captions for []
# 9hE6NT7y2ZY attempt_download called
# 9hE6NT7y2ZY Audio downloaded
# 9hE6NT7y2ZY Found captions for []
# 26mZboENjd4 attempt_download called
# 26mZboENjd4 Audio downloaded
# 26mZboENjd4 Found captions for [<Caption lang="English (auto-generated)" code="a.en">]
# 26mZboENjd4 Downloaded a.en captions
# QuYLHok8ZyY attempt_download called
# QuYLHok8ZyY Skipping, found existing folder.
# Ending with 303 videos

# %%
import glob
from moviepy.editor import AudioFileClip

def static_analysis(location):
    folders = {x for x in os.listdir(location)}
    print("Videos crawled:", len(folders))
    print()
    
    has_audio = 0
    has_at_least_one_transcript = 0
    
    total_bytes = 0
    total_length = 0
    transcripts = {}   

    for folder in folders:
        if not os.path.exists(location + folder + "/audio.mp4"):
            continue        
        has_audio += 1
        with AudioFileClip(location + folder + "/audio.mp4") as audio:
            total_length += audio.duration
        total_bytes += os.path.getsize(location + folder + "/audio.mp4")
        has_transcript = False
        for file in os.listdir(location + folder):
            if ".json" in file:
                has_transcript = True
                language = file.replace("caption-", "").replace(".json", "")
                if language not in transcripts:
                    transcripts[language] = 0
                transcripts[language] += 1
        if has_transcript:
            has_at_least_one_transcript += 1
        
    print("Downloaded mp4 Files:", has_audio)
    print("Total mp4 Audio Duration (seconds):", int(total_length))
    print("Total mp4 Filesize (bytes):", total_bytes)
    print()
    
    transcripts = sorted(transcripts.items(), key=lambda item: item[1], reverse=True)
    print("Has at least one transcript:", has_at_least_one_transcript)
    for language, count in transcripts:
        print("Transcripts of language", language + ":", count)

static_analysis("dataset/")
# Out:
# Videos crawled: 309
#
# Downloaded mp4 Files: 293
# Total mp4 Audio Duration (seconds): 127077
# Total mp4 Filesize (bytes): 775100442
#
# Has at least one transcript: 261
# Transcripts of language a.en: 242
# Transcripts of language en.uYU-mmqFLq8: 65
# Transcripts of language en.JkeT_87f4cc: 55
# Transcripts of language en-US: 29
# Transcripts of language en.nP7-2PuUl7o: 25
# Transcripts of language en: 15
# Transcripts of language en.dQs7zDoAYDs: 4
# Transcripts of language en.IbbGYl6aSTg: 1
# Transcripts of language en.YhZ6GAzbjEg: 1
# Transcripts of language en.RTbB2cpHawQ: 1
# Transcripts of language en-GB: 1
# Transcripts of language en.LoGGid9nkGE: 1
# Transcripts of language en.I1eY0-195hw: 1
# Transcripts of language en.PkKg-NMw-yM: 1
# Transcripts of language en.0irEcW9boG4: 1
